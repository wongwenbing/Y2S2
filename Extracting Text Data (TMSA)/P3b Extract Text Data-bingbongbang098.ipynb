# %% [markdown]
# ![NYPLogo.png](attachment:NYPLogo.png)
#
# # Practical 3b: Extract Text Data
#
# ## Objectives
# * Demonstrate different methods of acquiring text data from different data sources.

# %% [markdown]
# ## Extract Text Data from PDFs
# Most of the time our data will be stored as PDF files. We need to extract text from these files and store it for further analysis.
#
# The simplest way to do this is by using the PyPDF2 libary.
#
# Follow the steps in this session to extract text data from PDF files.
#
#
# ### Install and import all the necessary libraries
# To install the PyPDF2 library:
# > Type this command in jupyter or anaconda prompt: **pip install pypdf2**
#
# ```Python
# # import libraries
# import PyPDF2
# from PyPDF2 import PdfFileReader
# ```

# %%
# !pip install pypdf2
# Out:
# Requirement already satisfied: pypdf2 in /opt/anaconda3/lib/python3.11/site-packages (3.0.1)

# %%
import PyPDF2
from PyPDF2 import PdfFileReader

# %% [markdown]
# ### Extracting text from PDF file
# Download the **sample.pdf** file and placed in the same directory as your Jupyter notebook or Python script.
#
# Now we will extract the text using the Python code below.
#
# Note that the codes above does not work for scanned PDFs.

# %%
pdf=open("sample.pdf","rb")
pdf_reader=PyPDF2.PdfReader(pdf)
page=pdf_reader.pages[0]
print(page.extract_text())
pdf.close()
# Out:
# Lorem Ipsum  is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been
# the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the
# 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with
# desktop publishing  software like Aldus PageMaker including versions of Lorem Ipsum.
#
# Lorem Ipsum  is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been
# the industry's standard dummy text ever since the 1500s, when an unknown printer took a galle y of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the
# 1960s with the release of Letraset sheets containing  Lorem Ipsum passages, and more recently with
# desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.
#
# Lorem Ipsum  is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been
# the industry's standard dummy  text ever since the 1500s, when an unknown printer took a galley of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electronic typesetting, remaining essentially unchanged. It was popular ised in the
# 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with
# desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.
#
# Lorem Ipsum  is simply dummy text of the printing and typesett ing industry. Lorem Ipsum has been
# the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electro nic typesetting, remaining essentially unchanged. It was popularised in the
# 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with
# desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum .
#
# Lorem Ipsum  is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been
# the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the
# 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with
# desktop publishing  software like Aldus PageMaker including versions of Lorem Ipsum.
#
# Lorem Ipsum  is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been
# the industry's standard dummy text ever since the 1500s, when an unknown printer took a galle y of
# type and scrambled it to make a type specimen book. It has survived not only five centuries, but also
# the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the
# 1960s with the release of Letraset sheets containing  Lorem Ipsum passages, and more recently with
# desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %% [markdown]
# ### Exercise
# Download the **sample2.pdf** and try the following tasks:
# 1. Read the all the pages in sample2.pdf and print out the extracted text
#
# <em>**Hint use loop to read all pages</em>

# %%
pdf=open("sample2.pdf","rb")
pdf_reader=PyPDF2.PdfReader(pdf)
count=len(pdf_reader.pages)
pages=[]
print(count)
for i in range(count):
    page=pdf_reader.pages[i]
    output=page.extract_text()
    # print(output)
    data={
        'page': i+1,
        'content':output
    }
    pages.append(data)
    
pages
# Out:
# 2
# [{'page': 1,
#   'content': ' A Simple PDF File \n This is a small demonstration .pdf file - \n just for use in the Virtual Mechanics tutorials. More text. And more \n text. And more text. And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. Boring, zzzzz. And more text. And more text. And \n more text. And more text. And more text. And more text. And more text. \n And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. And more text. Even more. Continued on page 2 ...'},
#  {'page': 2,
#   'content': ' Simple PDF File 2 \n ...continued from page 1. Yet more text. And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. Oh, how boring typing this stuff. But not as boring as watching \n paint dry. And more text. And more text. And more text. And more text. \n Boring.  More, a little more text. The end, and just as well. '}]

# %% [markdown]
# ## Extract Text Data from Word Files
# Word files are one of the most common files that an organisation deals with. We need to extract text from these files and store it for further analysis.
#
# The simplest way to do this is by using the docx libary.
#
# Follow the steps in this session to extract text data from Word files.
#
#
# ### Install and import all the necessary libraries
# To install the docx library:
# > Type this command in jupyter or anaconda prompt: **pip install python-docx**
#
# ```Python
# # import library
# from docx import Document
# ```

# %%
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in /opt/anaconda3/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from python-docx) (4.11.0)

# %%
from docx import Document

# %% [markdown]
# ### Extracting text from PDF file
# Download the **sample.docx** file and placed in the same directory as your Jupyter notebook or Python script.
#
# Now we will extract the text using the Python code below.

# %%
# create a word file object
doc = open("sample.docx", "rb")

# create word reader object
doc = Document(doc)

# create an empty string and call this document. This document variable store each paragraph in the Word document.
# We then create a for loop that goes through each paragraph in the Word document and appends the paragraph.
docu=""
for para in doc.paragraphs:
    docu += para.text

# print the extract text
print(docu)
# Out:
# Curabitur bibendum ante urna, sed blandit libero egestas id. Pellentesque rhoncus elit in lacus ultrices fringilla. Nam ac metus eu turpis mattis rutrum. Mauris mattis sem ex, facilisis molestie sapien luctus non. Vestibulum tincidunt urna at odio suscipit, vel congue felis cursus. Etiam tellus magna, egestas ac suscipit in, laoreet quis felis. Proin non orci id dui tincidunt egestas.Vestibulum eleifend, ligula a scelerisque vehicula, risus justo ultricies ligula, et interdum lorem ex eget ex. Duis dignissim lacus vitae velit laoreet, vitae placerat velit aliquet. Etiam eget mollis nulla, ac vehicula mi. Etiam non sollicitudin velit, imperdiet commodo mi. Fusce quis tellus tellus. Donec dictum euismod risus non tempus. Duis quis pellentesque nunc. Praesent elementum condimentum mollis.Phasellus dapibus quam a hendrerit placerat. Sed ultrices blandit nulla sed sodales. Nunc quis volutpat eros. Etiam bibendum eu tellus consequat blandit. Curabitur lacinia cursus diam sed pharetra. Proin molestie tristique mauris ut aliquam. Donec purus odio, molestie id suscipit sit amet, porttitor in erat. Vestibulum ut tellus vel mi lobortis porta nec vel tellus. Quisque pretium blandit dignissim. Proin eu metus convallis sapien efficitur mollis. Nunc luctus ex in nunc ornare, nec blandit orci faucibus. Aenean bibendum mi vel neque euismod hendrerit. Vestibulum ac pharetra magna. Ut rutrum, orci at blandit faucibus, justo mauris iaculis mauris, ut tempor lectus risus at ligula.Duis non tincidunt purus. Nam quis sapien risus. Donec mattis convallis tempor. Fusce aliquam aliquet eros, nec rutrum lectus pretium at. Praesent blandit justo a mi dignissim placerat. Ut ullamcorper elit eget diam maximus iaculis. In bibendum in massa eget facilisis. In iaculis lectus nec neque vehicula, ac molestie ante ornare. Sed sit amet sem mollis, egestas justo ac, rhoncus nunc. In in aliquam ante, non imperdiet ante. Mauris in sapien ut quam hendrerit mollis. Proin feugiat dignissim nisi, sed tincidunt ante aliquam et. Integer finibus et augue a tempus.Nullam facilisis quis nisl sit amet iaculis. Integer hendrerit metus in faucibus aliquet. Donec fermentum, lacus lobortis pulvinar vestibulum, felis ipsum auctor mi, ac pulvinar lacus magna semper ligula. Proin mollis eros turpis, vel iaculis velit lobortis vitae. Nam hendrerit arcu quam, ac feugiat massa semper eu. Nullam quis feugiat nisl. Praesent fringilla luctus purus non pulvinar. Donec accumsan purus libero, eget maximus purus consequat faucibus. Maecenas porta consectetur magna non commodo.Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Ut facilisis nibh quis pellentesque dapibus. Aliquam vulputate porta ex, eu convallis neque luctus a. Vivamus egestas dignissim neque, ac vestibulum tortor finibus eu. In condimentum lorem ac nulla bibendum, sit amet dapibus nisl maximus. Donec eu neque nec enim eleifend dictum vitae eu orci. Maecenas id consequat augue, congue molestie nibh. Proin in mi et nunc bibendum convallis. Nullam eu sagittis elit. Quisque interdum turpis at nulla mollis, quis ultricies lacus rutrum. Sed molestie accumsan metus, ut rutrum mi ullamcorper sed. Vivamus eu imperdiet mauris, in pulvinar orci. Cras nec feugiat velit. Curabitur varius mattis mi, ac rutrum ligula convallis lacinia. Phasellus iaculis diam quam, et egestas libero mollis sed.Duis vel erat dolor. Phasellus ut sem non elit tempor convallis. Nunc non fermentum leo, eget rhoncus eros. Mauris varius condimentum metus, aliquet vulputate quam vestibulum sed. Etiam vel diam nec velit viverra laoreet id eu purus. Nunc vulputate magna ac nisl tempor bibendum. Morbi vitae tempor velit. Nam auctor nisi est, id pharetra leo accumsan quis. Suspendisse id urna libero. Curabitur congue ante ut lorem placerat hendrerit. Phasellus faucibus felis a nulla volutpat, ut tempor erat vulputate. Mauris pellentesque faucibus mattis. Integer cursus egestas ligula ac sodales. Nam blandit massa sit amet ex venen ...

# %% [markdown]
# ## Extracting Text Data from RSS Feeds
# RSS (Rich Site Summary) is a format for delivering regularly change web content. Many news-related sites, weblogs and other online publishers syndicate their content as an RSS Feed to whoever wants it.
#
# The simplest way to do this is by using the feedparser libary.
#
# Follow the steps in this session to extract text data from RSS feeds.
#
#
# ### Install and import all the necessary libraries
# To install the feedparser library:
# > Type this command in jupyter or anaconda prompt: **pip install feedparser**

# %%
# !pip install feedparser
# Out:
# Requirement already satisfied: feedparser in /opt/anaconda3/lib/python3.11/site-packages (6.0.11)
# Requirement already satisfied: sgmllib3k in /opt/anaconda3/lib/python3.11/site-packages (from feedparser) (1.0.0)

# %%
import feedparser
import pandas as pd

# %% [markdown]
# ### Feed Structure
# In the below example, we will get the structure of the feed so that we can analyse further about which parts of the feed want to process. Use the feedparser.parse() function for creating a feed object which contains parsed blog. It takes the URL of the blog feed.
# ```Python
# # create feed and put in the RSS feed url
# news_feed = feedparser.parse("https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=10416")
#
# news_feed.keys()
# ```
# Feed has some general information about the rss feed, but the "meat" of the feed is in entries. The rest of the keys weren't all that useful.
# ```Python
# # get keys under entries
# news_feed.entries[0].keys()
# ```

# %%
# create feed and put in the RSS feed url
news_feed = feedparser.parse("https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=10416")

news_feed.keys()

# get keys under entries
news_feed.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'published', 'published_parsed', 'id', 'guidislink', 'tags', 'media_thumbnail', 'href'])

# %% [markdown]
# ### Get Details of Feed
# RSS documents often know as feed which consists of text, and metadata, like time and author's name.

# %%
# returns title of rss feed
print(news_feed.feed.title)

# return link of rss feed and number of entries
print(news_feed.feed.link)
print(len(news_feed.entries))

# details of individual entries can be accessed by using attribute nam
print(news_feed.entries[0].title)
print(news_feed.entries[0].link)
print(news_feed.entries[0].published)
# Out:
# Latest News
# https://www.channelnewsasia.com/
# 20
# Shine Muscat grapes in Singapore safe to eat, says SFA after Thai contamination concerns
# https://www.channelnewsasia.com/singapore/shine-muscat-grapes-thailand-pesticides-chemical-contamination-4712196
# Wed, 30 Oct 2024 20:58:00 +0800

# %% [markdown]
# ### Exercise
# Try the following tasks:
# 1. Read this rss feed: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml
# 2. Save the entries title, link, published into a dataframe

# %%
news_feed = feedparser.parse("https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml")

news_feed.keys()

# get keys under entries
news_feed.entries[0].keys()
news=[]
for i in range(len(news_feed.entries)): 
    title=news_feed.entries[i].title
    link=news_feed.entries[i].link
    data={
        'title':title,
        'link':link
    }
    news.append(data)

# %%
news
# Out:
# [{'title': 'Scientists in Argentina unearth oldest tadpole, from dinosaur times',
#   'link': 'https://www.channelnewsasia.com/business/scientists-argentina-unearth-oldest-tadpole-dinosaur-times-4713436'},
#  {'title': 'Alphabet says Spotify, Paramount sign to use new cloud chip',
#   'link': 'https://www.channelnewsasia.com/business/alphabet-says-spotify-paramount-sign-use-new-cloud-chip-4713441'},
#  {'title': 'Apple launches new, more powerful versions of MacBook Pro',
#   'link': 'https://www.channelnewsasia.com/business/apple-launches-new-more-powerful-versions-macbook-pro-4713311'},
#  {'title': 'England prop Marler restores X account after haka post furore',
#   'link': 'https://www.channelnewsasia.com/sport/england-prop-marler-restores-x-account-after-haka-post-furore-4713196'},
#  {'title': 'Former Ferrari strategy head Rueda joins Sauber F1 team',
#   'link': 'https://www.channelnewsasia.com/'},
#  {'title': 'Chinese EV giant BYD net profit up 11.5%, beats Tesla in quarterly revenue for first time',
#   'link': 'https://www.channelnewsasia.com/business/byd-profit-revenue-tesla-electric-vehicles-4712831'},
#  {'title': 'Chinese EV giant BYD net profit up 11.5%, beats Tesla in quarterly revenue for first time',
#   'link': 'https://www.channelnewsasia.com/business/byd-profit-revenue-tesla-electric-vehicles-4712831'},
#  {'title': 'Super Micro Computer says Ernst & Young resigns as auditor, shares tank',
#   'link': 'https://www.channelnewsasia.com/business/super-micro-computer-says-ernst-young-resigns-auditor-shares-tank-4713071'},
#  {'title': "Van Nistelrooy honoured to serve as Man United's interim manager",
#   'link': 'https://www.channelnewsasia.com/sport/van-nistelrooy-honoured-serve-man-uniteds-interim-manager-4713031'},
#  {'title': 'Klopp defends decision to join Red Bull as global head of football',
#   'link': 'https://www.channelnewsasia.com/sport/klopp-defends-decision-join-red-bull-global-head-football-4713036'},
#  {'title': 'Shine Muscat grapes in Singapore safe to eat, says SFA after Thai contamination concerns',
#   'link': 'https://www.channelnewsasia.com/singapore/shine-muscat-grapes-thailand-pesticides-chemical-contamination-4712196'},
#  {'title': 'Shine Muscat grapes in Singapore safe to eat, says SFA after Thai contamination concerns',
#   'link': 'https://www.channelnewsasia.com/singapore/shine-muscat-grapes-thailand-pesticides-chemical-contamination-4712196'},
#  {'title': "Man City's Miedema undergoes knee surgery",
#   'link': 'https://www.channelnewsasia.com/sport/man-citys-miedema-undergoes-knee-surgery-4713021'},
#  {'title': 'CDW misses quarterly revenue estimates on slow hardware solutions demand',
#   'link': 'https://www.channelnewsasia.com/business/cdw-misses-quarterly-revenue-estimates-slow-hardware-solutions-demand-4713011'},
#  {'title': 'Stamford Catering Services allowed to resume operations after suspension due to 160 gastroenteritis cases',
#   'link': 'https://www.channelnewsasia.com/singapore/sfa-lifts-suspension-stamford-catering-services-gastroenteritis-4712881'},
#  {'title': "Scientists rebuild the face of 400-year-old Polish 'vampire'",
#   'link': 'https://www.channelnewsasia.com/business/scientists-rebuild-face-400-year-old-polish-vampire-4712901'},
#  {'title': 'EU tariffs on Chinese electric cars based on WTO rules, Renault boss says',
#   'link': 'https://www.channelnewsasia.com/business/eu-tariffs-chinese-electric-cars-based-wto-rules-renault-boss-says-4712861'},
#  {'title': 'Garmin raises full-year guidance, results beat amid unabated demand',
#   'link': 'https://www.channelnewsasia.com/business/garmin-raises-full-year-guidance-results-beat-amid-unabated-demand-4712826'},
#  {'title': 'BYD appoints former Stellantis UK chief Davino to push European expansion',
#   'link': 'https://www.channelnewsasia.com/business/byd-appoints-former-stellantis-uk-chief-davino-push-european-expansion-4712816'},
#  {'title': "UEFA pledges 1 billion euros in six-year plan to develop women's football",
#   'link': 'https://www.channelnewsasia.com/sport/uefa-pledges-1-billion-euros-six-year-plan-develop-womens-football-4712771'}]

# %%
news=pd.DataFrame(news)
news
# Out:
#                                                 title  \
# 0   Scientists in Argentina unearth oldest tadpole...
# 1   Alphabet says Spotify, Paramount sign to use n...
# 2   Apple launches new, more powerful versions of ...
# 3   England prop Marler restores X account after h...
# 4   Former Ferrari strategy head Rueda joins Saube...
# 5   Chinese EV giant BYD net profit up 11.5%, beat...
# 6   Chinese EV giant BYD net profit up 11.5%, beat...
# 7   Super Micro Computer says Ernst & Young resign...
# 8   Van Nistelrooy honoured to serve as Man United...
# 9   Klopp defends decision to join Red Bull as glo...
# 10  Shine Muscat grapes in Singapore safe to eat, ...
# 11  Shine Muscat grapes in Singapore safe to eat, ...
# 12          Man City's Miedema undergoes knee surgery
# 13  CDW misses quarterly revenue estimates on slow...
# 14  Stamford Catering Services allowed to resume o...
# 15  Scientists rebuild the face of 400-year-old Po...
# 16  EU tariffs on Chinese electric cars based on W...
# 17  Garmin raises full-year guidance, results beat...
# 18  BYD appoints former Stellantis UK chief Davino...
# 19  UEFA pledges 1 billion euros in six-year plan ...
#
#                                                  link
# 0   https://www.channelnewsasia.com/business/scien...
# 1   https://www.channelnewsasia.com/business/alpha...
# 2   https://www.channelnewsasia.com/business/apple...
# 3   https://www.channelnewsasia.com/sport/england-...
# 4                    https://www.channelnewsasia.com/
# 5   https://www.channelnewsasia.com/business/byd-p...
# 6   https://www.channelnewsasia.com/business/byd-p...
# 7   https://www.channelnewsasia.com/business/super...
# 8   https://www.channelnewsasia.com/sport/van-nist...
# 9   https://www.channelnewsasia.com/sport/klopp-de...
# 10  https://www.channelnewsasia.com/singapore/shin...
# 11  https://www.channelnewsasia.com/singapore/shin...
# 12  https://www.channelnewsasia.com/sport/man-city...
# 13  https://www.channelnewsasia.com/business/cdw-m...
# 14  https://www.channelnewsasia.com/singapore/sfa-...
# 15  https://www.channelnewsasia.com/business/scien...
# 16  https://www.channelnewsasia.com/business/eu-ta...
# 17  https://www.channelnewsasia.com/business/garmi...
# 18  https://www.channelnewsasia.com/business/byd-a...
# 19  https://www.channelnewsasia.com/sport/uefa-ple...

# %%
news.to_excel('news_feed.xlsx')

# %% [markdown]
# ## Extracting Text Data from Twitter
# Twitter has a gigantic amount of data with a lot of value in it. Social media marketers are making their living from it. There is an enormous amount of tweets every day, and every tweet has some story to tell. When all of this data is collected and analysed, it gives a tremendous amount of insights to a business about their company, product, service, etc.
#
# In February 2023, Twitter set unrealistic prices for its API, giving away crumbs of data for big bucks. Some started using libraries such as snscrape, which used web public APIs. But in April 2023, Twitter closed that option as well — making search only for authorized accounts.
#
# In the exercise below to use Python to scrape data from Twitter. With Twitter's recent changes and restricting use of its API this will be a super useful method to allow you to extract narrow time data from Twitter.
#
# In order to scrape our data we are going to use the scrapper API. To use API  you first have to create an account so you can go ahead and go to scrapperapi.com. Click on **Get Started for Free** to sign up for an account. After creating the account, it will give you an API key that you need in the code later.
#
# ### Install and import all the necessary libraries
# First we need to import two libraries. The first one is request which is what we will be using to make sure HTTP requests to actually go out to the web and scrape data. We'll also import pandas to get the data we scrape from twitter back into data frames.
#
# ```Python
# # import the libraries
# import requests
# import pandas as pd
# ```

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Extracting text from API
# Once all the credentials are in place, use the code below to fetch the data.
#
# We will create a payload parameter that contain the parameters that will dictate how our search works so the first thing we will pass in the API key that you can retrieve from the scraper API. Next we will pass in the query. This query is your search query that you want the scrape from Twitter. Let's say we want to get more information on artificial intelligence. Then we are going to pass in the number of responses or the number of tweets we want to scrape so in this case we are going to do 25.
#
# After which, we will set a request and pass in a link to the scraper API together with our payload parameters. We will get a response in return with some data and we want that in json format.
#
# ```Python
# payload = {
#     'api_key': 'REPLACE ME',
#     'query': 'artificial intelligence',
#     'num': '10'
# }
#
# response = requests.get('https://api.scraperapi.com/structured/twitter/search', params=payload)
# data = response.json()
# ```

# %%
payload = {
    'api_key': '8f8bba013ff7e1b0208f6cad7a52494a',
    'query': 'man utd',
    'num': '100'
}

response = requests.get('https://api.scraperapi.com/structured/twitter/search', params=payload)
data = response.json()

# %% [markdown]
# Let's take a look at the data and the keys. We can see that we have three keys: search_information, organic_results and pagination. From the organic_results, you can see there is title, and the snippet from the tweet and it gives you the link and the displayed link.
#
# If we look at the pagination, it give you some additional metadata about your data pool. The information that we wanted are in the organic_results.
#
# ~~~Python
# print (data.keys())
# data['organic_results']
# ~~~

# %%
print(data.keys())
data['organic_results']
# Out:
# dict_keys(['search_information', 'organic_results', 'videos', 'images', 'pagination'])
# [{'position': 0,
#   'title': 'Laurie Whitwell (@lauriewhitwell) / ...',
#   'snippet': "West Ham 2 Man Utd 1 – Dalot's horror miss, penalty drama and is Ten Hag's time up? From nytimes.com.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/lauriewhitwell',
#   'displayed_link': '389.7K+ followers'},
#  {'position': 1,
#   'title': 'Fabrizio Romano',
#   'snippet': 'Manchester United and Sporting are again in direct contact today about 30 day notice period for Rúben Amorim. Man Utd see it as normal\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/FabrizioRomano/status/1851638542868336848',
#   'displayed_link': '20.6K+ likes  ·  1 hour ago'},
#  {'position': 2,
#   'title': 'Man United News (@ManUtdMEN) / X',
#   'snippet': "How Man United should line up in Ruud van Nistelrooy's first game in charge · 3 ; Man Utd 'target' four Sporting Lisbon stars after Amorim as exit claim emerges.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdmen',
#   'displayed_link': '2M+ followers'},
#  {'position': 3,
#   'title': '🔰 Totally Man Utd™ 🔰 (@TotallyMUFC) ...',
#   'snippet': "#MUFC #GlazersOut #LUHG · m.facebook.com/TotallyMUFC/ Joined July 2012. 970 Following · 133.9K Followers · Posts · Replies · Media. Totally Man Utd™ 's posts.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/totallymufc',
#   'displayed_link': '134K+ followers'},
#  {'position': 4,
#   'title': 'UF (@UtdFaithfuls) / X',
#   'snippet': 'Man Utd and European football • DM for business, enquiries, promos • @Gamdom.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/utdfaithfuls',
#   'displayed_link': '443.4K+ followers'},
#  {'position': 5,
#   'title': 'DHL Man Utd (@DHLManUtd) / X',
#   'snippet': "DHL Man Utd's posts ; Aug 5. Delivering a Difference: @ManUtd. legend. @louissaha. joins the incredible DHL Disaster Response Team ❤️   Don't miss the action —\xa0...",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/dhlmanutd',
#   'displayed_link': '103.9K+ followers'},
#  {'position': 6,
#   'title': 'Man Utd News (@RooVanMataZaj) ...',
#   'snippet': 'Andre Onana is the first Man Utd goalkeeper since David De Gea transfermarkt.co.uk/manchester-uni… 101.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/roovanmatazaj',
#   'displayed_link': '4.4K+ followers'},
#  {'position': 7,
#   'title': 'Man Utd Stuff (@ManUtdStuff) / X',
#   'snippet': "Man Utd Stuff's posts ; Jul 18, 2018. | Pogba's moving speech to the French squad before the World Cup final. Leader. Embedded video. 0:56 ; Sep 1. \u200d♂️. Image.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdstuff',
#   'displayed_link': '156.8K+ followers'},
#  {'position': 8,
#   'title': 'Men in Blazers',
#   'snippet': "Next Man Utd Manager: Ruben Amorim. The 39-year-old led Sporting to Portuguese title in '20-21, ending a 19-year drought via high-pressing\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MenInBlazers/status/1851330773632323690',
#   'displayed_link': '30+ likes  ·  21 hours ago'},
#  {'position': 9,
#   'title': 'UtdDistrict',
#   'snippet': "Mainoo, Collyer, Yoro – What will Ruben Amorim's Man Utd side look like? From utddistrict.co.uk.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/utddistrict',
#   'displayed_link': '925K+ followers'},
#  {'position': 10,
#   'title': 'BBC Sport',
#   'snippet': 'What will Ruben Amorim bring to Man Utd? Sporting say Man Utd are ready to pay his 10m euros (£8.3m) release clause.',
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/BBCSport/status/1851308552100495790',
#   'displayed_link': '90+ likes  ·  23 hours ago'},
#  {'position': 11,
#   'title': 'Nick (@ManUnitedYouth) / X',
#   'snippet': 'Alan Shearer on West Ham\'s penalty: "Awful decision. That\'s a terrible decision whether you like Man Utd or not, and I don\'t understand why Michael Oliver got\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manunitedyouth',
#   'displayed_link': '65.1K+ followers'},
#  {'position': 12,
#   'title': 'Samuel Luckhurst (@samuelluckhurst) / X',
#   'snippet': 'LEAKED - Man Utd Interim Boss Ruud Van Nistelrooy reacts badly to receiving his new company car… Embedded video. 0:\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/samuelluckhurst',
#   'displayed_link': '626.4K+ followers'},
#  {'position': 13,
#   'title': 'Out Of Context Man Utd',
#   'snippet': "Out Of Context Man Utd's posts ... Kobbie Mainoo trying to get on Manchester City's private jet to the Ballon d'Or ceremony. ... Every third game HE is on the bench\xa0...",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/manutdnocontext',
#   'displayed_link': '37.9K+ followers'},
#  {'position': 14,
#   'title': 'Man Utd The Religion (@ManUtdTheRelig) / X',
#   'snippet': "“We will keep fighting for Man Utd and we will go again on Wednesday” Erik ten Hag. ... It's daylight robbery because Man Utd have dominated this match but the\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/manutdtherelig',
#   'displayed_link': '7.6K+ followers'},
#  {'position': 15,
#   'title': 'Man Utd Boston (@ManUtdBoston) ...',
#   'snippet': 'is the new home for Man Utd Boston and will be hosting every match this season. The Dubliner is the most authentic Irish Pub in the city and we are so\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdboston',
#   'displayed_link': '1.6K+ followers'},
#  {'position': 16,
#   'title': 'Mark Ogden (@MarkOgden_) / X',
#   'snippet': "Man Utd have made their worst ever start to a PL season and it's down to a series of big mistakes. How Man United have been turned into Premier League also\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/markogden_',
#   'displayed_link': '287.6K+ followers'},
#  {'position': 17,
#   'title': 'Simon Stone (@sistoney67) / X',
#   'snippet': "Football latest: Man Utd in Amorim talks & Ballon d'Or reaction to Yamal, Rodri, Kane, Bonmati. Latest news as Man Utd talk to Ruben Amorim after Erik ten\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/sistoney67',
#   'displayed_link': '427K+ followers'},
#  {'position': 18,
#   'title': 'Dan Roan',
#   'snippet': 'EXCLUSIVE: Man Utd co-owner Sir Jim Ratcliffe tells me about under-pressure manager Erik ten Hag: “I like Eric.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/danroan/status/1842212222820376813',
#   'displayed_link': '1.4K+ likes  ·  3 weeks ago'},
#  {'position': 19,
#   'title': 'Mirror Football',
#   'snippet': "Leicester boss highlights Man Utd changes as he talks up Foxes' chances at Old Trafford https://t.co/Ut7lhVMIFr.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MirrorFootball/status/1851653848873742529',
#   'displayed_link': '6 likes  ·  22 minutes ago'},
#  {'position': 20,
#   'title': 'Man Utd should hire Thomas Frank',
#   'snippet': 'Man Utd should hire Thomas Frank. 1:30 AM · Oct 30, 2024. ·. 33. Views.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/xpCarty/status/1851436472798212121',
#   'displayed_link': '14 hours ago'},
#  {'position': 21,
#   'title': 'UF',
#   'snippet': "... Ruben Amorim to complete the season at Sporting. The agreement is now DONE, and he's Man Utd's new manager. Now time for documents and.",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/UtdFaithfuls/status/1851307787625668654',
#   'displayed_link': 'https://twitter.com › UtdFaithfuls › status'},
#  {'position': 22,
#   'title': 'Neil Custis (@ncustisTheSun) / X',
#   'snippet': "Man Utd squad release open letter to fans 'We want more days like yesterday. We are excited for the future here. There is so much that we have to achieve\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ncustisthesun',
#   'displayed_link': '90K+ followers'},
#  {'position': 23,
#   'title': 'David Ornstein (@David_Ornstein) ...',
#   'snippet': "& more on Ten Hag's exit & #MUFC's pursuit of Amorim. Inside Man Utd's pursuit of Amorim and Ten\xa0...",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/david_ornstein',
#   'displayed_link': '3.1M+ followers'},
#  {'position': 28,
#   'title': "Ruud van Nistelrooy urges Man Utd to turn season around ' ...",
#   'snippet': "Ruud van Nistelrooy urges Man Utd to turn season around 'while we have time' #TelegraphFootball | #MUFC.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/TeleFootball/status/1851588921802527040',
#   'displayed_link': '40+ likes  ·  4 hours ago'},
#  {'position': 29,
#   'title': 'The Sun - Man Utd',
#   'snippet': 'Follow all the latest news, transfer gossip and match updates on Man Utd from @TheSunFootball @SunSport.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/sunmanutd',
#   'displayed_link': '64K+ followers'},
#  {'position': 30,
#   'title': 'Opta Analyst',
#   'snippet': "Why Man Utd Want Ruben Amorim With Man Utd closing in on their replacement for Erik ten Hag, we look at Amorim's: Winning mentality\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/OptaAnalyst/status/1851558014852952178',
#   'displayed_link': '7 likes  ·  6 hours ago'},
#  {'position': 31,
#   'title': 'Devils in the Details – A Podcast About Man Utd',
#   'snippet': "Devils in the Details – A Podcast About Man Utd's posts ; Nov 30, 2022. From the bottom of our hearts, thank you so much · 1 · 77 ; 1h. Now taking Amorim specific\xa0...",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/devilsitdpod',
#   'displayed_link': '4K+ followers'},
#  {'position': 32,
#   'title': 'Man Utd Vault (@ManUtdvault) / X',
#   'snippet': "Man Utd Vault's posts ... New book !! “Manchester United – Postcards From The Past” tells the story of Manchester United from the early days of Newton Heath to\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdvault',
#   'displayed_link': '7.2K+ followers'},
#  {'position': 33,
#   'title': 'Fabrizio Romano (@FabrizioRomano) ...',
#   'snippet': 'Sporting confirm formal communication received from #MUFC for Amorim to be appointed. Amorim has already said yes to Man Utd proposal and project. Image. 4K.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/fabrizioromano',
#   'displayed_link': '22.7M+ followers'},
#  {'position': 34,
#   'title': 'Mark Goldbridge (@markgoldbridge) / ...',
#   'snippet': 'Mark Goldbridge reposted · Square profile picture · The United Stand · @UnitedStandMUFC. ·. Oct 29. How AMORIM Will Set Up Man Utd https://buff.ly/3Yskkgy #MUFC.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/markgoldbridge',
#   'displayed_link': '928.6K+ followers'},
#  {'position': 35,
#   'title': 'Man Utd Fanboy (@utd_fanboy) / X',
#   'snippet': "Man Utd Fanboy's posts ... Wonder what courtois thought of that save ? ... Hi carla do you remember when my good mate and your boss at the time nailed you in the\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/utd_fanboy',
#   'displayed_link': '3 followers'},
#  {'position': 36,
#   'title': 'Man Utd Talk (@ManUtdTalk_) / X',
#   'snippet': "Man Utd Talk's posts ... Manchester United was the first team to have a sweeper keeper called Fabien Barthez. Don't believe me, take a look. ... Morning all, wait\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ManUtdTalk_',
#   'displayed_link': '3.5K+ followers'},
#  {'position': 37,
#   'title': '🔰 Flex 🔰 (@FlexUTD) / X',
#   'snippet': '"DELUSIONAL FROM DAY ONE!" Ten Hag SACKED, Amorim Next Man Utd... Flex is joined by Alex Crook, Angelina Kelly, Hugh Woozencroft, and German football\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/flexutd',
#   'displayed_link': '229K+ followers'},
#  {'position': 38,
#   'title': 'Man Utd fans.. Sorry o… E ku iroju... This too shall not pass',
#   'snippet': 'Man Utd fans.. Sorry o… E ku iroju... This too shall not pass.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/KolaShangOne/status/1850569609268621690',
#   'displayed_link': '3 days ago'},
#  {'position': 39,
#   'title': 'MUFC Ticket Alerts (@TicketManUtd) / ...',
#   'snippet': 'We alert you when Man Utd release home tickets on their website (Not affiliated with Manchester United F.C.) Instant alerts: https://t.co/QjYBtvxyqE.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ticketmanutd',
#   'displayed_link': '10.2K+ followers'},
#  {'position': 40,
#   'title': 'Man Utd Facebook (@MUFC_Facebook) / X',
#   'snippet': ". Personal: @Aleczandxr. Everywhere in the world Joined May 2012. 323 Following · 17.5K Followers · Posts · Replies · Media. Man Utd Facebook's posts. Pinned.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/mufc_facebook',
#   'displayed_link': '17.5K+ followers'},
#  {'position': 41,
#   'title': 'Mirror Football',
#   'snippet': "Man Utd's pursuit of Ruben Amorim is facing a delay due to his 30-day notice period at Sporting Lisbon Explained\xa0...",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/MirrorFootball/status/1851598316326334854',
#   'displayed_link': '10+ likes  ·  4 hours ago'},
#  {'position': 42,
#   'title': 'Man Utd have confirmed the departure of Erik ten Hag',
#   'snippet': 'Man Utd have confirmed the departure of Erik ten Hag. Image. 11:54 AM · Oct 28, 2024. ·. 216.6K. Views. 1,360. Reposts · 458. Quotes.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1850868770840936505',
#   'displayed_link': '6.6K+ likes'},
#  {'position': 43,
#   'title': 'UtdTruthful',
#   'snippet': 'Official UtdTruthful: Covering Man Utd updates, stats, transfer, quotes + pictures and more.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/utdtruthful',
#   'displayed_link': '45.4K+ followers'},
#  {'position': 44,
#   'title': 'Premier League',
#   'snippet': '@premierleague. Club legend Ruud van Nistelrooy is ready to get going in the Man Utd dugout ❤️. Image. 2:06 PM · Oct 30, 2024. ·. 92.1K. Views.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1851626688846745804',
#   'displayed_link': '1.7K+ likes  ·  2 hours ago'},
#  {'position': 45,
#   'title': 'Mr Miyagi - Ten Hag has kompromat on the Man Utd owners.',
#   'snippet': 'Log in · Sign up. Conversation. Mr Miyagi · @TheOreAfolayan. Ten Hag has kompromat on the Man Utd owners. 4:29 PM · Oct 27, 2024. ·. 167. Views.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/TheOreAfolayan/status/1850575575007547712',
#   'displayed_link': 'https://twitter.com › TheOreAfolayan › status'},
#  {'position': 46,
#   'title': 'BBC Sport',
#   'snippet': 'Erik ten Hag\'s future at Man Utd seems to be in doubt. But would his departure be right thing for the club? @AndyMitten: "Fans are sick\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/BBCSport/status/1794333919610822758',
#   'displayed_link': '1.2K+ likes  ·  5 months ago'},
#  {'position': 47,
#   'title': 'Thoughts on our Aston Villa/Man Utd combined 11 ahead ...',
#   'snippet': "Thoughts on our Aston Villa/Man Utd combined 11 ahead of today's game? #AVLMUN.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ForgedStout/status/1842853415778455726',
#   'displayed_link': '60+ likes  ·  3 weeks ago'},
#  {'position': 48,
#   'title': 'Virgil van Dijk',
#   'snippet': 'Probably my goal against Man Utd. 7:48 PM · Mar 31, 2020 · 399. Reposts · 111. Quotes · 4,873. Likes. 5. Bookmarks. 5.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/VirgilvDijk/status/1245075410548928513',
#   'displayed_link': '4.9K+ likes'},
#  {'position': 49,
#   'title': 'ITV Football',
#   'snippet': 'Jonny Evans misses for Man Utd and Man City are Community Shield champions #ITVFootball | #CommunityShield.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/itvfootball/status/1822304725288583277',
#   'displayed_link': '90+ likes  ·  2 months ago'},
#  {'position': 50,
#   'title': 'Adam Crafton',
#   'snippet': 'Increasingly feel like my adulthood supporting Man Utd is retribution for my childhood supporting Man Utd.',
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/AdamCrafton_/status/1489730243602563073',
#   'displayed_link': '21.3K+ likes  ·  2 years ago'},
#  {'position': 51,
#   'title': 'Mirror Football',
#   'snippet': 'Dwight Yorke has named the Man Utd players he thinks got Erik ten Hag sacked https://t.co/oPXGMVkP0B.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MirrorFootball/status/1851578292794437896',
#   'displayed_link': '4 likes  ·  5 hours ago'},
#  {'position': 52,
#   'title': 'BBC Sport',
#   'snippet': 'Ruben Amorim said at a news conference on Monday that he was expecting to be asked about Man Utd, but that he was not prepared to talk about\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/BBCSport/status/1851004019390759346',
#   'displayed_link': '160+ likes  ·  1 day ago'},
#  {'position': 53,
#   'title': 'Manchester United - ManUtd',
#   'snippet': "“I've been supporting Man Utd since I was six years old. My mother actually grew up in Manchester – she always talked about going to United games.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ManUtd/status/1817607661824675871',
#   'displayed_link': '9K+ likes  ·  3 months ago'},
#  {'position': 54,
#   'title': 'Man Utd Stats (@unitedstats99) / X',
#   'snippet': 'Manchester United Statistics & Data Analysis. United Historian. Season Ticket holder Andy Graham 47. First Match: Man Utd 1-0 Southampton 28-09-1985. #mufc.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/unitedstats99',
#   'displayed_link': '2K+ followers'},
#  {'position': 55,
#   'title': 'CBS Sports Golazo',
#   'snippet': 'Man Utd have their third of the day! Scott McTominay finishes off a wonderful counterattack.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/CBSSportsGolazo/status/1729939144774730010',
#   'displayed_link': '130+ likes  ·  11 months ago'},
#  {'position': 56,
#   'title': 'Mirror Football',
#   'snippet': 'NEW: Man Utd have got the green light from rivals Man City to make their move for Ruben Amorim - with City having no plans to appoint the\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MirrorFootball/status/1851230548124987554',
#   'displayed_link': '10+ likes  ·  1 day ago'},
#  {'position': 57,
#   'title': 'MCIMUN Man City vs Man Utd Fixture news.',
#   'snippet': 'The social media fixture name for Man City vs Man Utd is #MCIMUN. The next match under this fixture name is March 2nd 2024.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/mcimun',
#   'displayed_link': '1.1K+ followers'},
#  {'position': 58,
#   'title': 'Man Utd FF (@ManUtdFF) / X',
#   'snippet': "Man Utd FF's posts ... Alejandro Garnacho got benched for liking an Instagram post about Cristiano Ronaldo speaking on Erik Ten Hag then comes on as a sub..",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdff',
#   'displayed_link': '21.2K+ followers'},
#  {'position': 59,
#   'title': 'Mark Ogden',
#   'snippet': "That's 17 goals conceded in Man Utd's last five European away games. 3,4,4,3,3. Lots of problems, but that's an obvious one.",
#   'highlighs': ["Man Utd's"],
#   'link': 'https://twitter.com/MarkOgden_/status/1841967094704787761',
#   'displayed_link': '180+ likes  ·  3 weeks ago'},
#  {'position': 60,
#   'title': '"Sporting\'s head coach Ruben Amorim has spoken on ...',
#   'snippet': "Sporting's head coach Ruben Amorim has spoken on his future, after the Portuguese club received an approach from Man Utd.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1851587740074127601',
#   'displayed_link': '1K+ likes  ·  4 hours ago'},
#  {'position': 61,
#   'title': 'Niall Horan',
#   'snippet': 'Went to man Utd and PSG tonight , thanks to the people @ManUtd for really looking after us , appreciate it ! Safe trip home.',
#   'highlighs': ['man Utd'],
#   'link': 'https://twitter.com/NiallOfficial/status/626613035239653376',
#   'displayed_link': '97.2K+ likes  ·  9 years ago'},
#  {'position': 62,
#   'title': 'Man Utd Frames (@MUFCFrames) / X',
#   'snippet': "Man Utd Frames's posts. Pinned ... Man Utd Frames · @MUFCFrames. ·. Feb 27, 2023. | Manchester United Carabao Cup celebration pictures (edited by us) [A\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/mufcframes',
#   'displayed_link': '5.8K+ followers'},
#  {'position': 63,
#   'title': 'Match of the Day on X: "8th place for Man Utd ...',
#   'snippet': "8th place for Man Utd ❌ It's their WORST EVER finish in Premier League history… #BBCFootball.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/BBCMOTD/status/1792241029359325369',
#   'displayed_link': '3.1K+ likes  ·  5 months ago'},
#  {'position': 64,
#   'title': 'MAN UTD 🔴 (@berekettsegay9) / X',
#   'snippet': "MAN UTD 's posts ... Amad's head is GONE, don't blame him. ... No puede ser. ... FAKE NEWS !!!! ❌❌❌ Ça en devient tellement prévisible, veille d'audience comme par\xa0...",
#   'highlighs': ['MAN UTD'],
#   'link': 'https://twitter.com/berekettsegay9',
#   'displayed_link': '340+ followers'},
#  {'position': 65,
#   'title': 'The xG Philosophy on X',
#   'snippet': '... City: +116.54(xG) ◎ Arsenal: +98.36(xG) ◎ Liverpool: +88.06(xG) ◎ Tottenham: +25.84(xG) ◎ Chelsea: +24.10(xG) ◎ Man Utd: -3.46(xG)',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/xGPhilosophy/status/1850955632436011022',
#   'displayed_link': '2.5K+ likes  ·  1 day ago'},
#  {'position': 66,
#   'title': 'Fergie is always checking in on the Man Utd score',
#   'snippet': 'Fergie is always checking in on the Man Utd score ❤️. Embedded video. 0:17. 9:16 AM · Oct 4, 2024. ·. 492.8K. Views.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/footballontnt/status/1842131747556712947',
#   'displayed_link': '6.9K+ likes'},
#  {'position': 67,
#   'title': 'Premier League',
#   'snippet': 'Remember the last time Man Utd went to Selhurst Park? A special strike from Michael Olise #CRYMUN.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1787526728828551235',
#   'displayed_link': '7.2K+ likes  ·  5 months ago'},
#  {'position': 71,
#   'title': 'Marcus Rashford',
#   'snippet': 'People want to know what Man Utd means to me!♥️. Image. 7:28 PM · May 25, 2024. ·. 5.3M. Views. 18.3K. Reposts · 3,460. Quotes.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MarcusRashford/status/1794450533987602841',
#   'displayed_link': '207.9K+ likes'},
#  {'position': 72,
#   'title': 'Man Utd Channel (@ManUtdChannel) / X',
#   'snippet': 'The greatest club in the world! ⚪️⚫️ Fan account, not affiliated with Man Utd. We do not upload videos/gifs, we only embed/share them.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdchannel',
#   'displayed_link': '54.1K+ followers'},
#  {'position': 73,
#   'title': 'Man Utd Fans Bantz (@ManUtdFanBantz) / ...',
#   'snippet': "... supporters. DM's open if interested. United Kingdom Joined November 2015. 244 Following · 389 Followers · Posts · Replies · Media. Man Utd Fans Bantz's posts.",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/manutdfanbantz',
#   'displayed_link': '380+ followers'},
#  {'position': 74,
#   'title': 'Days Since Man Utd Last Won The CHAMPIONS LEAGUE',
#   'snippet': "... Joined December 2014. 3 Following · 9,848 Followers · Posts · Replies · Media. Days Since Man Utd Last Won The CHAMPIONS LEAGUE's posts. Days Since Man Utd\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/dayssincemanutd',
#   'displayed_link': '9.8K+ followers'},
#  {'position': 75,
#   'title': 'Jamie Hamilton',
#   'snippet': 'Man Utd now have the potential to be the most tactically interesting team in the PL. If Ten Hag (or whoever is coaching them!)',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/stirling_j/status/1835615355965722763',
#   'displayed_link': '650+ likes  ·  1 month ago'},
#  {'position': 76,
#   'title': 'Man utd should get a ball playing number 10.. and ...',
#   'snippet': 'Man utd should get a ball playing number 10.. and see the team improve.',
#   'highlighs': ['Man utd'],
#   'link': 'https://twitter.com/neckobi/status/1850559829657489718',
#   'displayed_link': '3 days ago'},
#  {'position': 77,
#   'title': 'UF on X: "🚨 - Man Utd staff and players traveling to ...',
#   'snippet': "Man Utd staff and players traveling to Brighton for tomorrow's game ♥️ [   - Ejcclips on TikTok]",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/UtdFaithfuls/status/1827065011111444855',
#   'displayed_link': '10K+ likes  ·  2 months ago'},
#  {'position': 78,
#   'title': 'Chris Eagles arrives for Man Utd legends game',
#   'snippet': 'Chris Eagles arrives for Man Utd legends game. Embedded video. 1:19. 6:36 AM · Sep 8, 2024. ·. 39K. Views. 20. Reposts.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/robbiemorgz/status/1832669388010295722',
#   'displayed_link': '420+ likes'},
#  {'position': 79,
#   'title': 'JJevafrass Music',
#   'snippet': 'Log in · Sign up. Conversation. JJevafrass Music · @JJevafrass. Man utd. 4:04 PM · Oct 27, 2024. ·. 54. Views. 1. Repost.',
#   'highlighs': ['Man utd'],
#   'link': 'https://twitter.com/JJevafrass/status/1850569281446031827',
#   'displayed_link': 'https://twitter.com › JJevafrass › status'},
#  {'position': 80,
#   'title': 'True Geordie',
#   'snippet': 'Last season when Man Utd secured top 4 and a cup I made this video about Ten Hag and got hammered for it The questions I asked have been\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/TrueGeordieTG/status/1787783937802076561',
#   'displayed_link': '300+ likes  ·  5 months ago'},
#  {'position': 81,
#   'title': 'Premier League',
#   'snippet': 'FULL-TIME Man Utd 2-1 Crystal Palace 10-man Man Utd secure their sixth straight home win in the #PL #MUNCRY.',
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1621916169585262593',
#   'displayed_link': '14.3K+ likes  ·  1 year ago'},
#  {'position': 82,
#   'title': 'Mirror Football',
#   'snippet': 'Man Utd facing crucial hours in Ruben Amorim talks with major agreement yet to be reached in Sporting Lisbon contract\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MirrorFootball/status/1851324967998071030',
#   'displayed_link': '20+ likes  ·  22 hours ago'},
#  {'position': 83,
#   'title': 'ITV Football',
#   'snippet': 'Man Utd show off another impressive move but Marcus Rashford cannot find the finish \u200d   #ITVFootball | #CommunityShield.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/itvfootball/status/1822281513460736486',
#   'displayed_link': '30+ likes  ·  2 months ago'},
#  {'position': 84,
#   'title': 'Days since Man Utd won the Premier League',
#   'snippet': "It has been 4169 days since Man Utd won the Premier League! They have spent more than any other PL team and still haven't won it!",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/dayssincemanu',
#   'displayed_link': '2.9K+ followers'},
#  {'position': 85,
#   'title': 'Paddy Power',
#   'snippet': 'Man Utd fans will be looking to build on a huge first weekend of the season... 18+ Be GambleAware.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/paddypower/status/1827045358960058821',
#   'displayed_link': '1.6K+ likes  ·  2 months ago'},
#  {'position': 86,
#   'title': 'CBS Sports Golazo',
#   'snippet': 'A Man Utd own goal puts Sevilla back in the tie.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/CBSSportsGolazo/status/1646616633212014593',
#   'displayed_link': '120+ likes  ·  1 year ago'},
#  {'position': 87,
#   'title': 'Why Man Utd will not make another Ole Gunnar Solskjaer ...',
#   'snippet': 'Why Man Utd will not make another Ole Gunnar Solskjaer out of Ruud van Nistelrooy ✍️ @JBurtTelegraph #TelegraphFootball | #MUFC.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/TeleFootball/status/1851291489109946804',
#   'displayed_link': '40+ likes  ·  1 day ago'},
#  {'position': 88,
#   'title': 'Premier League',
#   'snippet': "FULL-TIME Leicester 4-2 Man Utd What a match! @LCFC end Man Utd's 29-match unbeaten run away from home in the #PL #LEIMUN.",
#   'highlighs': ['Man Utd', "Man Utd's"],
#   'link': 'https://twitter.com/premierleague/status/1449403948985630720',
#   'displayed_link': '7.1K+ likes  ·  3 years ago'},
#  {'position': 89,
#   'title': 'BBC Sport',
#   'snippet': 'There are two new faces at Man Utd. Matthijs de Ligt and Noussair Mazraoui have joined from Bayern Munich. Lisandro Martinez is excited to\xa0...',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/BBCSport/status/1823447771422077149',
#   'displayed_link': '6.6K+ likes  ·  2 months ago'},
#  {'position': 90,
#   'title': 'Arne Slot the last time Man Utd won the league...',
#   'snippet': 'Arne Slot the last time Man Utd won the league... Image. 4:22 PM · Aug 5, 2024. ·. 259.1K. Views. 214. Reposts.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/LfcShaunjudge/status/1820495578369065415',
#   'displayed_link': '4.4K+ likes'},
#  {'position': 91,
#   'title': 'Graham Ruthven',
#   'snippet': 'Why Man Utd fired ETH! Why ETH failed at MU! Who will replace ETH? @TotalSoccerShow The Big Thing https://t.co/ju1oPbXawD.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/grahamruthven/status/1851318446480638362',
#   'displayed_link': '3 likes  ·  22 hours ago'},
#  {'position': 92,
#   'title': 'Neil Custis',
#   'snippet': 'Man Utd have banned me 7 times - latest media block reminds me of a Fergie spat https://t.co/qKOPgONB2m.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/ncustisTheSun/status/1787789579887493545',
#   'displayed_link': '70+ likes  ·  5 months ago'},
#  {'position': 93,
#   'title': 'Startup MAN UTD (@StartupManutd) ...',
#   'snippet': 'What a star we have on our hands. Man utd are so lucky to have him. A reminder that he only made his debut a few months ago and is still a very young kid\xa0...',
#   'highlighs': ['Man utd'],
#   'link': 'https://twitter.com/StartupManutd',
#   'displayed_link': '1K+ followers'},
#  {'position': 94,
#   'title': 'Man Utd: ThroughTheLens (@ManUnitedLens) / ...',
#   'snippet': "... past & present. Joined September 2020. 732 Following · 1,212 Followers · Posts · Replies · Media. Man Utd: ThroughTheLens's posts. Pinned. Man Utd:\xa0...",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/ManUnitedLens',
#   'displayed_link': '1.2K+ followers'},
#  {'position': 95,
#   'title': 'Mirror Football',
#   'snippet': 'Only one Man Utd player can hold their head up after that shocking performance at Anfield.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/MirrorFootball/status/1516544672478339082',
#   'displayed_link': '10+ likes  ·  2 years ago'},
#  {'position': 96,
#   'title': 'Anirudh Ravichander',
#   'snippet': 'Great game between Man Utd and Madrid even though we were on the losing side.Unlucky that the referee screwed up!Congrats to all Madrid fans.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/anirudhofficial/status/309061248266424322',
#   'displayed_link': '20+ likes  ·  11 years ago'},
#  {'position': 97,
#   'title': '"Who should be the next permanent Man Utd manager ...',
#   'snippet': 'Who should be the next permanent Man Utd manager? #TelegraphFootball | #MUFC.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/TeleFootball/status/1850871978179113242',
#   'displayed_link': 'https://twitter.com › TeleFootball › status'},
#  {'position': 98,
#   'title': '"Man Utd funniest team tbh. This has been an ...',
#   'snippet': 'Man Utd funniest team tbh. This has been an amazing 3 months as the number one United supporter.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/jaycaspiankang/status/1849558498453094532',
#   'displayed_link': '7 likes  ·  5 days ago'},
#  {'position': 99,
#   'title': 'Man Utd have work to do in the race for European football - X',
#   'snippet': 'Premier League · @premierleague. Man Utd have work to do in the race for European football. Image. 9:15 PM · May 6, 2024. ·. 859.2K. Views.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/premierleague/status/1787592107516920055',
#   'displayed_link': '14.8K+ likes'},
#  {'position': 100,
#   'title': 'Labiolly37 on X',
#   'snippet': 'Man Utd are facing this team next in the PL? Ten Hag is so dead.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/Labiolly37/status/1841583943054705007',
#   'displayed_link': '4 weeks ago'},
#  {'position': 101,
#   'title': 'GOAL on X: "Cristiano Ronaldo at Man Utd was special 🎯 ...',
#   'snippet': 'Cristiano Ronaldo at Man Utd was special. Embedded video. 0:06. From. Manchester United · 10:55 AM · Aug 12, 2021.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/goal/status/1425772978726477825',
#   'displayed_link': '5.2K+ likes  ·  3 years ago'},
#  {'position': 102,
#   'title': 'GOAL',
#   'snippet': 'This picture of Antony with the Man Utd fans. Image. Antony Santos and Manchester United · 8:40 PM · Oct 22, 2022.',
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/goal/status/1583921307774689283',
#   'displayed_link': '8.5K+ likes  ·  2 years ago'},
#  {'position': 103,
#   'title': 'Man Utd Weekly Pod (@UtdWeeklyPod) ...',
#   'snippet': "... -social.co.uk/podcast/manche… Joined January 2016. 45 Following · 1,216 Followers · Posts · Replies · Media. Man Utd Weekly Pod's posts. Man Utd Weekly Pod.",
#   'highlighs': ['Man Utd', 'Man Utd'],
#   'link': 'https://twitter.com/utdweeklypod',
#   'displayed_link': '1.2K+ followers'},
#  {'position': 104,
#   'title': 'UF',
#   'snippet': "CEO Omar Berrada's FULL message to Man Utd fans ahead of the new season which begins tomorrow: “Dear fans, “Welcome back to Old Trafford for our first Premier\xa0...",
#   'highlighs': ['Man Utd'],
#   'link': 'https://twitter.com/UtdFaithfuls/status/1824011678696038412',
#   'displayed_link': '36.7K+ likes  ·  2 months ago'}]

# %% [markdown]
# Let's look at the type that was returned for organic_results. We can see that it is a list so we can actually access certain elements of organic results. Each element within that list is a dictionary and we can use the keys to access more data.

# %%
# data type of organic_results
print (type(data['organic_results']))

# get first element of organic_results
display(data['organic_results'][0])

# get the title of the first tweet
print (data['organic_results'][0]['title'])
# Out:
# <class 'list'>
# {'position': 0,
#  'title': 'Laurie Whitwell (@lauriewhitwell) / ...',
#  'snippet': "West Ham 2 Man Utd 1 – Dalot's horror miss, penalty drama and is Ten Hag's time up? From nytimes.com.",
#  'highlighs': ['Man Utd'],
#  'link': 'https://twitter.com/lauriewhitwell',
#  'displayed_link': '389.7K+ followers'}
# Laurie Whitwell (@lauriewhitwell) / ...

# %% [markdown]
# Next, we will convert our scrape data to a dataframe. First we need to iterate through the tweets in the organic_results and placed it in a twitter_data list. Using the list we will create a dataframe.

# %%
twitter_data = []
for tweet in data['organic_results']:
    twitter_data.append(tweet)
    
df = pd.DataFrame(twitter_data)
df
# Out:
#     position                                              title  \
# 0          0            Laurie Whitwell (@lauriewhitwell) / ...
# 1          1                                    Fabrizio Romano
# 2          2                   Man United News (@ManUtdMEN) / X
# 3          3            🔰 Totally Man Utd™ 🔰 (@TotallyMUFC) ...
# 4          4                             UF (@UtdFaithfuls) / X
# ..       ...                                                ...
# 93       100                                    Labiolly37 on X
# 94       101  GOAL on X: "Cristiano Ronaldo at Man Utd was s...
# 95       102                                               GOAL
# 96       103             Man Utd Weekly Pod (@UtdWeeklyPod) ...
# 97       104                                                 UF
#
#                                               snippet           highlighs  \
# 0   West Ham 2 Man Utd 1 – Dalot's horror miss, pe...           [Man Utd]
# 1   Manchester United and Sporting are again in di...           [Man Utd]
# 2   How Man United should line up in Ruud van Nist...           [Man Utd]
# 3   #MUFC #GlazersOut #LUHG · m.facebook.com/Total...           [Man Utd]
# 4   Man Utd and European football • DM for busines...           [Man Utd]
# ..                                                ...                 ...
# 93  Man Utd are facing this team next in the PL? T...           [Man Utd]
# 94  Cristiano Ronaldo at Man Utd was special. Embe...           [Man Utd]
# 95  This picture of Antony with the Man Utd fans. ...           [Man Utd]
# 96  ... -social.co.uk/podcast/manche… Joined Janua...  [Man Utd, Man Utd]
# 97  CEO Omar Berrada's FULL message to Man Utd fan...           [Man Utd]
#
#                                                  link  \
# 0                  https://twitter.com/lauriewhitwell
# 1   https://twitter.com/FabrizioRomano/status/1851...
# 2                       https://twitter.com/manutdmen
# 3                     https://twitter.com/totallymufc
# 4                    https://twitter.com/utdfaithfuls
# ..                                                ...
# 93  https://twitter.com/Labiolly37/status/18415839...
# 94  https://twitter.com/goal/status/14257729787264...
# 95  https://twitter.com/goal/status/15839213077746...
# 96                   https://twitter.com/utdweeklypod
# 97  https://twitter.com/UtdFaithfuls/status/182401...
#
#                    displayed_link
# 0               389.7K+ followers
# 1     20.6K+ likes  ·  1 hour ago
# 2                   2M+ followers
# 3                 134K+ followers
# 4               443.4K+ followers
# ..                            ...
# 93                    4 weeks ago
# 94    5.2K+ likes  ·  3 years ago
# 95    8.5K+ likes  ·  2 years ago
# 96                1.2K+ followers
# 97  36.7K+ likes  ·  2 months ago
#
# [98 rows x 6 columns]

# %% [markdown]
# ### Exercise
# Try the following tasks:
# 1. Scrape 50 tweets from Twitter on "**chatgpt**"
# 2. Save the scrape results into a dataframe

# %%
payload = {
    'api_key': '8f8bba013ff7e1b0208f6cad7a52494a',
    'query': 'chatgpt',
    'num': '50'
}

response = requests.get('https://api.scraperapi.com/structured/twitter/search', params=payload)
data = response.json()

print(data.keys())
data['organic_results']

# data type of organic_results
print (type(data['organic_results']))

# get first element of organic_results
display(data['organic_results'][0])

# get the title of the first tweet
print (data['organic_results'][0]['title'])

twitter_data = []
for tweet in data['organic_results']:
    twitter_data.append(tweet)
    
df = pd.DataFrame(twitter_data)
df
# Out:
# dict_keys(['search_information', 'organic_results', 'pagination'])
# <class 'list'>
# {'position': 0,
#  'title': 'ChatGPT (@ChatGPTapp) / X',
#  'snippet': 'The desktop app for macOS now gives you side-by-side access to ChatGPT. Use Option + Space to open a companion window, which stays in front so you can use it\xa0...',
#  'highlighs': ['ChatGPT'],
#  'link': 'https://twitter.com/chatgptapp',
#  'displayed_link': '269.6K+ followers'}
# ChatGPT (@ChatGPTapp) / X
#     position                                              title  \
# 0          0                          ChatGPT (@ChatGPTapp) / X
# 1          1                                             OpenAI
# 2          2                                             OpenAI
# 3          3                                             OpenAI
# 4          4                                             OpenAI
# 5          5            The ChatGPT Report (@ChatGPTReport) / X
# 6          6  OpenAI on X: "ChatGPT can now browse the inter...
# 7          7                                             OpenAI
# 8          8                                             OpenAI
# 9          9                                             OpenAI
# 10        10                                             OpenAI
# 11        11                                             OpenAI
# 12        12                                  OpenAI Developers
# 13        13                                             OpenAI
# 14        14         ChatGPT for Google (@chatgpt4google) / ...
# 15        15                                             OpenAI
# 16        16                                        Tobias Mann
# 17        17                                             OpenAI
# 18        18                            How Do You Use ChatGPT?
# 19        19  "We're sharing an update on the advanced Voice...
# 20        20                                             OpenAI
# 21        21  "ChatGPT is not a tool for doing. It's a tool ...
# 22        22                                            ChatGPT
# 23        23                                    Allie K. Miller
# 24        24                                      Conor Grennan
# 25        25       The ChatGPT app for iOS is now available ...
# 26        26  today we launched ChatGPT. try talking with it...
# 27        27                                            Nothing
# 28        28                                             OpenAI
# 29        29  Sam Altman on X: "ChatGPT is incredibly limite...
# 30        30                                  BeyondBacktesting
# 31        31                                      Greg Brockman
# 32        32                                      Jeremy Howard
# 33        33  Kol Tregaskes - ChatGPT Canvas Observations + ...
# 34        34  Rory Stewart appears to have been using ChatGP...
# 35        35                       Justine Moore - venturetwins
# 36        36                                         Nick Dobos
# 37        37                                        Neil Gaiman
# 38        38                                      Mckay Wrigley
# 39        39  Ben Tossell - All the best examples of ChatGPT...
# 40        40                             Sam Altman (@sama) / X
# 41        41  "We took ChatGPT offline Monday to fix a bug i...
# 42        42                                         Jay Peters
# 43        43  "ChatGPT launched on wednesday. today it cross...
# 44        44                                            Jim Fan
# 45        45                                          Kent Beck
# 46        46                                        Mark Gurman
# 47        47  I made ChatGPT take a full SAT test. Here's ho...
# 48        48  ChatGPT just crossed 1 million users - Greg Br...
# 49        49  Brendan Dolan-Gavitt on X: "ChatGPT exploits a...
#
#                                               snippet  \
# 0   The desktop app for macOS now gives you side-b...
# 1   We're starting to roll out the ability to sear...
# 2   ChatGPT with voice is now available to all fre...
# 3   Today, ChatGPT Plus, Enterprise, Team, and Edu...
# 4   We're testing ChatGPT's ability to remember th...
# 5   The ChatGPT Report's posts ... Disney will rep...
# 6   ChatGPT can now browse the internet to provide...
# 7   ChatGPT can now see, hear, and speak. Rolling ...
# 8   We're rolling out an early version of canvas—a...
# 9   Just ask ChatGPT to create an image for a slid...
# 10  The ChatGPT desktop app for macOS is now avail...
# 11  We're starting to roll out advanced Voice Mode...
# 12  Introducing canvas—your coding surface in Chat...
# 13  ChatGPT can now read responses to you. On iOS ...
# 14  An open-source browser extension that enhances...
# 15  ... real time: https://t.co/MYHZB79UqN Text an...
# 16  ChatGPT is down, but don't worry you can spin ...
# 17  Using Memory is easy: just start a new chat an...
# 18  @ChatGPT. in their work and their lives—and sh...
# 19  ... rolling this out in alpha to a small group...
# 20  We've heard questions about how we chose the v...
# 21  ChatGPT is not a tool for doing. It's a tool f...
# 22  Log in · Sign up. @chatgpt. Account suspended....
# 23  OpenAI just released the ChatGPT iOS app an ho...
# 24  ChatGPT just quietly rolled out some major int...
# 25  The ChatGPT app for iOS is now available to us...
# 26  today we launched ChatGPT. try talking with it...
# 27  ChatGPT on-the-go. Alongside Ear and Ear (a), ...
# 28  We are piloting ChatGPT Plus, a subscription p...
# 29  ChatGPT is incredibly limited, but good enough...
# 30  ChatGPT is Dead, Love Live ChatGPT ChatGPT-4 i...
# 31  Just launched ChatGPT, our new AI system which...
# 32  Now that ChatGPT has rolled out custom instruc...
# 33  ChatGPT Canvas Observations + Wish-List Firstl...
# 34  Rory Stewart appears to have been using ChatGP...
# 35  Wild example of ChatGPT code switching. Embedd...
# 36  inside chatGPT using a 1079 char prompt We got...
# 37  @neilhimself Some more disturbing interactions...
# 38  ChatGPT just killed Siri. You can now: - use C...
# 39  All the best examples of ChatGPT, from OpenAI:...
# 40  ... to happen so fast, it's that the past happ...
# 41  We took ChatGPT offline Monday to fix a bug in...
# 42  OpenAI's ChatGPT Mac app had been storing conv...
# 43  ChatGPT launched on wednesday. today it crosse...
# 44  ChatGPT was launched last year on the 3rd day ...
# 45  I've been reluctant to try ChatGPT. Today I go...
# 46  I believe ChatGPT has been banned/on the list ...
# 47  Log in · Sign up. Conversation. david · @david...
# 48  ChatGPT just crossed 1 million users; it's bee...
# 49  ChatGPT exploits a buffer overflow. Image. 10:...
#
#                       highlighs  \
# 0                     [ChatGPT]
# 1                     [ChatGPT]
# 2                     [ChatGPT]
# 3                     [ChatGPT]
# 4                   [ChatGPT's]
# 5                     [ChatGPT]
# 6                     [ChatGPT]
# 7            [ChatGPT, ChatGPT]
# 8                     [ChatGPT]
# 9                     [ChatGPT]
# 10           [ChatGPT, ChatGPT]
# 11                    [ChatGPT]
# 12                    [ChatGPT]
# 13                    [ChatGPT]
# 14                    [ChatGPT]
# 15                    [ChatGPT]
# 16                    [ChatGPT]
# 17                    [ChatGPT]
# 18                    [ChatGPT]
# 19                    [ChatGPT]
# 20                    [ChatGPT]
# 21                    [ChatGPT]
# 22                    [chatgpt]
# 23                    [ChatGPT]
# 24                    [ChatGPT]
# 25                    [ChatGPT]
# 26                    [ChatGPT]
# 27           [ChatGPT, ChatGPT]
# 28                    [ChatGPT]
# 29                    [ChatGPT]
# 30   [ChatGPT, ChatGPT ChatGPT]
# 31                    [ChatGPT]
# 32                    [ChatGPT]
# 33           [ChatGPT, ChatGPT]
# 34                    [ChatGPT]
# 35                    [ChatGPT]
# 36                    [chatGPT]
# 37                    [ChatGPT]
# 38  [ChatGPT, ChatGPT, ChatGPT]
# 39                    [ChatGPT]
# 40                  [ChatGPT's]
# 41                    [ChatGPT]
# 42                    [ChatGPT]
# 43                    [ChatGPT]
# 44                    [ChatGPT]
# 45                    [ChatGPT]
# 46           [ChatGPT, ChatGPT]
# 47                    [ChatGPT]
# 48                    [ChatGPT]
# 49                    [ChatGPT]
#
#                                                  link  \
# 0                      https://twitter.com/chatgptapp
# 1                          https://twitter.com/openai
# 2   https://twitter.com/OpenAI/status/172706516618...
# 3   https://twitter.com/OpenAI/status/184695706720...
# 4   https://twitter.com/OpenAI/status/175746999774...
# 5                   https://twitter.com/chatgptreport
# 6   https://twitter.com/OpenAI/status/170707771004...
# 7   https://twitter.com/OpenAI/status/170628061842...
# 8   https://twitter.com/OpenAI/status/184188770702...
# 9   https://twitter.com/OpenAI/status/182164490484...
# 10  https://twitter.com/OpenAI/status/180567934243...
# 11  https://twitter.com/OpenAI/status/181835358027...
# 12  https://twitter.com/OpenAIDevs/status/18418880...
# 13  https://twitter.com/OpenAI/status/176471243293...
# 14                 https://twitter.com/chatgpt4google
# 15  https://twitter.com/OpenAI/status/179007217411...
# 16  https://twitter.com/Tobias_Writes/status/17980...
# 17  https://twitter.com/OpenAI/status/178499279666...
# 18  https://twitter.com/danshipper/status/17248118...
# 19  https://twitter.com/OpenAI/status/180571639352...
# 20  https://twitter.com/OpenAI/status/179244357583...
# 21  https://twitter.com/3lvis/status/1839666194640...
# 22                        https://twitter.com/chatgpt
# 23  https://twitter.com/alliekmiller/status/165926...
# 24  https://twitter.com/conorgrennan/status/184589...
# 25  https://twitter.com/OpenAI/status/166148801327...
# 26  https://twitter.com/sama/status/15980388155996...
# 27  https://twitter.com/nothing/status/17901497670...
# 28  https://twitter.com/OpenAI/status/162084658994...
# 29  https://twitter.com/sama/status/16017312957924...
# 30  https://twitter.com/BBacktesting/status/178822...
# 31  https://twitter.com/gdb/status/159801562754063...
# 32  https://twitter.com/jeremyphoward/status/16894...
# 33  https://twitter.com/koltregaskes/status/184194...
# 34  https://twitter.com/GazTheJourno/status/180914...
# 35  https://twitter.com/venturetwins/status/183968...
# 36  https://twitter.com/NickADobos/status/16821388...
# 37  https://twitter.com/neilhimself/status/1639610...
# 38  https://twitter.com/mckaywrigley/status/166688...
# 39  https://twitter.com/bentossell/status/15982696...
# 40                           https://twitter.com/sama
# 41  https://twitter.com/OpenAI/status/163929736172...
# 42  https://twitter.com/jaypeters/status/180857989...
# 43  https://twitter.com/sama/status/15996688082850...
# 44  https://twitter.com/DrJimFan/status/1733904000...
# 45  https://twitter.com/KentBeck/status/1648413998...
# 46  https://twitter.com/markgurman/status/16593715...
# 47  https://twitter.com/davidtsong/status/15987673...
# 48  https://twitter.com/gdb/status/159968310414243...
# 49  https://twitter.com/moyix/status/1598081204846...
#
#                                   displayed_link
# 0                              269.6K+ followers
# 1                                3.7M+ followers
# 2          https://twitter.com › OpenAI › status
# 3                     4.4K+ likes  ·  1 week ago
# 4                   6.2K+ likes  ·  8 months ago
# 5                                1.8K+ followers
# 6                    52.8K+ likes  ·  1 year ago
# 7                      40K+ likes  ·  1 year ago
# 8                    9.7K+ likes  ·  3 weeks ago
# 9                   3.5K+ likes  ·  2 months ago
# 10                  7.2K+ likes  ·  4 months ago
# 11                  7.2K+ likes  ·  3 months ago
# 12                   5.1K+ likes  ·  3 weeks ago
# 13                  4.6K+ likes  ·  8 months ago
# 14                               5.8K+ followers
# 15                 60.3K+ likes  ·  5 months ago
# 16  https://twitter.com › Tobias_Writes › status
# 17                  5.4K+ likes  ·  6 months ago
# 18                  630+ likes  ·  11 months ago
# 19         https://twitter.com › OpenAI › status
# 20         https://twitter.com › OpenAI › status
# 21                                        1 like
# 22                 https://twitter.com › chatgpt
# 23                     180+ likes  ·  1 year ago
# 24                       3 likes  ·  2 weeks ago
# 25                    1.3K+ likes  ·  1 year ago
# 26                   29.4K+ likes  ·  1 year ago
# 27                  2.7K+ likes  ·  5 months ago
# 28                    9.6K+ likes  ·  1 year ago
# 29                   27.2K+ likes  ·  1 year ago
# 30                      4 likes  ·  5 months ago
# 31                    2.3K+ likes  ·  1 year ago
# 32                    6.7K+ likes  ·  1 year ago
# 33                     60+ likes  ·  3 weeks ago
# 34                    10+ likes  ·  3 months ago
# 35                                    850+ likes
# 36                    2.4K+ likes  ·  1 year ago
# 37                     11K+ likes  ·  1 year ago
# 38                    2.4K+ likes  ·  1 year ago
# 39                                  14.4K+ likes
# 40                    https://twitter.com › sama
# 41                      8K+ likes  ·  1 year ago
# 42                    50+ likes  ·  3 months ago
# 43                                    49K+ likes
# 44       https://twitter.com › DrJimFan › status
# 45                    5.8K+ likes  ·  1 year ago
# 46                     460+ likes  ·  1 year ago
# 47                   13.6K+ likes  ·  1 year ago
# 48                    1.6K+ likes  ·  1 year ago
# 49                                   6.1K+ likes

# %%
df.to_excel("gpt_twitter.xlsx")

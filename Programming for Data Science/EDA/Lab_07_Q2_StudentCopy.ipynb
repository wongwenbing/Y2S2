# %% [markdown]
# # Practical 7
# # Q2 - Data Visualization with Python

# %% [markdown]
# ### Step 1 - Let us start by importing the required libraries

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Current version of Seaborn generates a bunch of warnings that we'll ignore in this tutorial
import warnings 
warnings.filterwarnings("ignore")

# Command to tell Python to actually display the graphs
# %matplotlib inline
sns.set()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\wongw\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\wongw\AppData\Roaming\Python\Python311\site-packages\traitlets\config\application.py", line 1046, in launch_instance
#     app.start()
# ...

# %% [markdown]
# ### Step 2 - Let read in the Dataset file into the DataFrame

# %%
# Type your Step 2 answer here
# Out:
#        month            vehicle_type  number
# 0    2012-01                    Cars  593555
# 1    2012-01             Rental Cars   13970
# 2    2012-01                    Taxi   27059
# 3    2012-01                   Buses   17037
# 4    2012-01  Goods & Other Vehicles  159854
# ..       ...                     ...     ...
# 439  2018-02             Rental cars   67931
# 440  2018-02                    Taxi   22440
# 441  2018-02                   Buses   19251
# 442  2018-02  Goods & Other Vehicles  162148
# 443  2018-02  Motorcycle and Scooter  140864
#
# [444 rows x 3 columns]

# %% [markdown]
# ### Step 3 - Let rename the month column into Year and Month the DataFrame
# |   Year  | Month |
# |---------|-------|
# |  2012   |   01  |
# |  2012   |   01  |
# |  2012   |   01  |
# |  2012   |   01  |
# |  2012   |   01  |

# %%
# Type your Step 3 answer here

# %%
# Type your Step 3 answer here
# Out:
#       0   1
# 0  2012  01
# 1  2012  01
# 2  2012  01
# 3  2012  01
# 4  2012  01

# %%
# Type your Step 3 answer here
# Out:
#    Year Month
# 0  2012    01
# 1  2012    01
# 2  2012    01
# 3  2012    01
# 4  2012    01

# %% [markdown]
# ### Step 4 - Convert the values in the "Year" column of the DataFrame month_split into numeric (integer) data type.

# %%
# Type your Step 4 answer here

# %%
# Type your Step 4 answer here
# Out:
#      Year  Month    month            vehicle_type  number
# 0    2012      1  2012-01                    Cars  593555
# 1    2012      1  2012-01             Rental Cars   13970
# 2    2012      1  2012-01                    Taxi   27059
# 3    2012      1  2012-01                   Buses   17037
# 4    2012      1  2012-01  Goods & Other Vehicles  159854
# ..    ...    ...      ...                     ...     ...
# 439  2018      2  2018-02             Rental cars   67931
# 440  2018      2  2018-02                    Taxi   22440
# 441  2018      2  2018-02                   Buses   19251
# 442  2018      2  2018-02  Goods & Other Vehicles  162148
# 443  2018      2  2018-02  Motorcycle and Scooter  140864
#
# [444 rows x 5 columns]

# %% [markdown]
# ### Step 5 - Drop the "month" column from the DataFrame.

# %%
# Type your Step 5 answer here
# Out:
#      Year  Month            vehicle_type  number
# 0    2012      1                    Cars  593555
# 1    2012      1             Rental Cars   13970
# 2    2012      1                    Taxi   27059
# 3    2012      1                   Buses   17037
# 4    2012      1  Goods & Other Vehicles  159854
# ..    ...    ...                     ...     ...
# 439  2018      2             Rental cars   67931
# 440  2018      2                    Taxi   22440
# 441  2018      2                   Buses   19251
# 442  2018      2  Goods & Other Vehicles  162148
# 443  2018      2  Motorcycle and Scooter  140864
#
# [444 rows x 4 columns]

# %% [markdown]
# ### Step 6 - Rename the numberical nos in the Month column to their respective month. e.g 1 to Jan, 12 to Dec

# %%
# Type your Step 6 answer here
# Out:
#      Year Month            vehicle_type  number
# 0    2012   Jan                    Cars  593555
# 1    2012   Jan             Rental Cars   13970
# 2    2012   Jan                    Taxi   27059
# 3    2012   Jan                   Buses   17037
# 4    2012   Jan  Goods & Other Vehicles  159854
# ..    ...   ...                     ...     ...
# 439  2018   Feb             Rental cars   67931
# 440  2018   Feb                    Taxi   22440
# 441  2018   Feb                   Buses   19251
# 442  2018   Feb  Goods & Other Vehicles  162148
# 443  2018   Feb  Motorcycle and Scooter  140864
#
# [444 rows x 4 columns]

# %% [markdown]
#  ### Step 7 - Display the count of each vehicle type and plot them with Bar Graph.

# %%
# Type your Step 7 answer here
# Out:
# vehicle_type
# Buses                     74
# Car                        7
# Cars                      67
# Goods & Other Vehicles    74
# Motorcycle and Scooter     7
# Motorcycles               67
# Rental Cars               67
# Rental cars                7
# Taxi                      74
# Name: number, dtype: int64

# %%
# Type your Step 7 answer here

# %% [markdown]
# ### Step 8 - As shown in the chart, there are vehicle types that represent similar types.
#
# E.g. Cars and Car, Rental Cars and Rental Cars, and Motorcycles, Motorcycle and Scooter.
#
# Change them to the same type and display the count of each vehicle type

# %%
# Type your Step 8 answer here

# %%
# Type your Step 8 answer here
# Out:
# vehicle_type
# Buses                     74
# Cars                      74
# Goods & Other Vehicles    74
# Motorcycle and Scooter    74
# Rental Cars               74
# Taxi                      74
# Name: number, dtype: int64

# %% [markdown]
# ### Step 9 - Based on the processed dataframe, plot the cars registered in 2013.

# %%
# Type your Step 9 answer here
# Out:
# 72     605947
# 78     605961
# 84     606026
# 90     605754
# 96     605882
# 102    606373
# 108    606492
# 114    606722
# 120    607191
# 126    607104
# 132    607079
# 138    607292
# Name: number, dtype: int64

# %%
# Type your Step 9 answer here

# %% [markdown]
# ### Step 10 - Plot the Motorcycle and Scooters registered in  2013

# %%
# Type your Step 10 answer here

# %% [markdown]
# ### Step 11 - Plot the following in 2 subplots.
#
# Compare the Cars registered in 2013 vs 2015
# Compare the Motorcycle and Scooter registered in 2013 vs 2015

# %%
# Type your Step 11 answer here

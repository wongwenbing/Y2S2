# %% [markdown]
# ![NYPLogo.png](attachment:NYPLogo.png)
#
# # Practical 5b: POS and NER
#
#
# ## Objectives
#
# - Perform Part-of-Speech (POS) tagging
# - Identify entities with raw text using Name Entity Recognition (NER)

# %% [markdown]
# ## Part-of-Speech (POS)
# Part-of-Speech tagging simply refers to assigning parts of speech to individual words in a sentence, which means that, unlike phrase matching, which is performed at the sentence or multi-word level, parts of speech tagging is performed at the token level.
#
# In corpus linguistics, **part-of-speech tagging** (POS tagging), also called **grammatical tagging** or **word-category disambiguation**. The POS tagger in the NLTK library outputs specific tags for certain words.
#
# Here’s some of the common tags, what they mean:

# %% [markdown]
# Tag|Description
# -|:-
# CC| coordinating conjunction
# DT| determiner
# IN| preposition/subordinating conjunction
# JJ| adjective ‘big’
# NN| noun, singular ‘desk’
# PRP| personal pronoun I, he, she
# RB| adverb very, silently
# UH| interjection
# VB| verb, base form take
#
# Text may contain stop words like ‘the’, ‘is’, ‘are’. We will filter the stop words from the text before doing the part-of-speech tagging.
#
# We will go through a sample program to illustrate how to do POS using a Python program.

# %% [markdown]
# ## Import libraries and download the packages
#
# ```Python
# import pandas as pd
#
# import nltk
# nltk.download('averaged_perceptron_tagger')
#
# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize, sent_tokenize
# stop_words = set(stopwords.words('english'))
# ```
# *NOTE: You have to use nltk.download() after installing it to get additional dependencies.*

# %%
#pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\textanalysis\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 20.1 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.9.1 regex-2024.11.6 tqdm-4.67.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# phik 0.12.4 requires matplotlib>=2.2.3, which is not installed.
# phik 0.12.4 requires scipy>=1.5.2, which is not installed.
# ydata-profiling 4.8.3 requires matplotlib<3.9,>=3.2, which is not installed.
# ydata-profiling 4.8.3 requires numba<1,>=0.56.0, which is not installed.
# ydata-profiling 4.8.3 requires scipy<1.14,>=1.4.1, which is not installed.
# ydata-profiling 4.8.3 requires seaborn<0.14,>=0.10.1, which is not installed.
# ydata-profiling 4.8.3 requires statsmodels<1,>=0.13.2, which is not installed.
# ydata-profiling 4.8.3 requires numpy<2,>=1.16.0, but you have numpy 2.1.3 which is incompatible.

# %%
# Enter code here
import pandas as pd

import nltk
nltk.download('averaged_perceptron_tagger')

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     D:\Users\24dit24a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %% [markdown]
# ## Read in File for analysis
# Next, we will read the file for analysis. For this practical we will be using Singapore News, **SGNews.csv**. This file must be placed in the same directory as your Jupyter notebook.
#
# Use Panda DataFrame to read in the data as follows:
#
# ![sgnews.png](attachment:sgnews.png)

# %%
# Read in SGNews.csv and display the first 5 lines of the data
df = pd.read_csv('SGNews.csv')
df.head()
# Out:
#                                                Title  \
# 0  Several Wang Learning Centre students to quara...
# 1  Pre-school outdoor activities reduced to 2 chi...
# 2  19 community cases among 31 new COVID-19 infec...
# 3  Pre-event testing to be subsidised for live pe...
# 4  COVID-19: Changi Airport to segregate flight a...
#
#                                                 Text
# 0  Eleven students and a teacher from Wang Learni...
# 1  Pre-schools will reduce the group size for out...
# 2  Nineteen community cases were among 31 new COV...
# 3  The Government will subsidise COVID-19 pre-eve...
# 4  Changi Airport will segregate flights and pass...

# %% [markdown]
# ## Using the POS-tagger in the NLTK library to tag the words
# The primary target of Part-of-Speech(POS) tagging is to identify the grammatical group of a given word. Whether it is a NOUN, PRONOUN, ADJECTIVE, VERB, ADVERBS, etc. based on the context. POS Tagging looks for relationships within the sentence and assigns a corresponding tag to the word.
#
# Before doing POS, we need to tokenize the data first.
#
# ```Python
# def tagPOS(text):
#     # Word tokenizers is used to find the words
#     wordsList = nltk.word_tokenize(text)
#
#     #  Using a Tagger. Which is part-of-speech tagger or POS-tagger.
#     tagged = nltk.pos_tag(wordsList)
#
#     return tagged
#
# ```
#
# Next we will use lamda to apply the **tagPOS** function to each review.
#
# ```Python
# df['POS_News'] = df['Text'].apply(lambda x: tagPOS(x))
# df.head()
# ```

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     D:\Users\24dit24a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     D:\Users\24dit24a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# True

# %%
# Enter codes here
def tagPOS(text):
    # Word tokenizers is used to find the words 
    wordsList = nltk.word_tokenize(text) 

    #  Using a Tagger. Which is part-of-speech tagger or POS-tagger.  
    tagged = nltk.pos_tag(wordsList) 
    
    return tagged

df['POS_News'] = df['Text'].apply(lambda x: tagPOS(x))  
df.head()
# Out:
#                                                Title  \
# 0  Several Wang Learning Centre students to quara...
# 1  Pre-school outdoor activities reduced to 2 chi...
# 2  19 community cases among 31 new COVID-19 infec...
# 3  Pre-event testing to be subsidised for live pe...
# 4  COVID-19: Changi Airport to segregate flight a...
#
#                                                 Text  \
# 0  Eleven students and a teacher from Wang Learni...
# 1  Pre-schools will reduce the group size for out...
# 2  Nineteen community cases were among 31 new COV...
# 3  The Government will subsidise COVID-19 pre-eve...
# 4  Changi Airport will segregate flights and pass...
#
#                                             POS_News
# 0  [(Eleven, JJ), (students, NNS), (and, CC), (a,...
# 1  [(Pre-schools, NNP), (will, MD), (reduce, VB),...
# 2  [(Nineteen, NNP), (community, NN), (cases, NNS...
# 3  [(The, DT), (Government, NNP), (will, MD), (su...
# 4  [(Changi, NNP), (Airport, NNP), (will, MD), (s...

# %% [markdown]
# ## To find specify tag from the tagged text
# We all know that sentences are made up of words belonging to different Parts of Speech (POS). There are eight different POS in the English language: **noun**, **pronoun**, **verb**, **adjective**, **adverb**, **preposition**, **conjunction**, and **intersection**.
#
# The POS determines how a specific word functions in meaning in a given sentence. For example, take the word “right”. In the sentence, “The boy was awarded chocolate for giving the right answer”, “right” is used as an adjective. Whereas, in the sentence, “You have the right to say whatever you want”, “right” is treated as a noun.
#
# This goes to show that the POS tag of a word carries a lot of significance when it comes to understanding the meaning of a sentence. And we can leverage it to extract meaningful information from our text. Research has shown the presence of adjectives and adverbs is usually a good indicator of text subjectivity. In other words, statements that use adjectives like “interesting,” “problematic” and “awesome” might be more likely to convey a subjective point of view than statements that do not include those adjectives.
#
# Next, we will define a `fingtags` function to find specify tag from the tagged text. The `fingtags` function will return the top N words based on the POS tag. You can define N to return more words if needed.
#
# ```Python
# # find the top N words based on the POS tag
# def findtags(tag_prefix, tagged_text, n):
#     cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
#                                   if tag.startswith(tag_prefix))
#     return dict((tag, cfd[tag].most_common(n)) for tag in cfd.conditions())
# ```
#
# Let's find the top 5 adjective (JJ) from the tenth review.
#
# ```Python
# # find the top 5 adjective in the first news
# tagged_text = df['POS_News'][0]
# tagdict = findtags('JJ', tagged_text, 5)
# for tag in sorted(tagdict):
#     print(tag, tagdict[tag])
# ```

# %%
# Enter codes here
def findtags(tag_prefix, tagged_text, n):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
                                  if tag.startswith(tag_prefix))
    return dict((tag, cfd[tag].most_common(n)) for tag in cfd.conditions())

tagged_text = df['POS_News'][0]
tagdict = findtags('JJ', tagged_text, 5)
for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# JJ [('positive', 2), ('same', 2), ('professional', 2), ('other', 2), ('Eleven', 1)]
# JJS [('latest', 1)]

# %% [markdown]
# ## Named Entity Recognition (NER)
# NER is a standard NLP problem which involves spotting named entities (people, places, organizations etc.) from a chunk of text, and classifying them into a predefined set of categories. Some of the practical applications of NER include:
# - Scanning news articles for the people, organizations and locations reported.
# - Providing concise features for search optimization: instead of searching the entire content, one may simply search for the major entities involved.
# - Quickly retrieving geographical locations talked about in Twitter posts.
#
# NER is a keyword extraction technique that uses natural language processing (NLP) to automatically identify named entities within raw text and classify them into predetermined categories, like people, organizations, email addresses, locations, values, etc.
#
# Before POS need to be done before NER can be performed. Once we have completed the parts-of-speech tagging, we will perform chunking. In simple terms, what chunking does is that it adds more structure to the sentence over and above the tagging. The output results in grouping of words called 'chunks'. In our example, we will only look at Nouns for the NER tagging.
#
# ```Python
# from nltk import ne_chunk
# nltk.download('words')
# nltk.download('maxent_ne_chunker')
#
# res_chunk = ne_chunk(tagged_text)
#
# for x in str(res_chunk).split('\n'):
#     if '/NN' in x:
#         print(x)
# ```

# %%
# Enter codes here
from nltk import ne_chunk
nltk.download('words')
nltk.download('maxent_ne_chunker')

res_chunk = ne_chunk(tagged_text)

for x in str(res_chunk).split('\n'):
    if '/NN' in x:
        print(x)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     D:\Users\24dit24a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     D:\Users\24dit24a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
#   students/NNS
#   teacher/NN
#   (PERSON Wang/NNP Learning/NNP Centre/NNP)
#   contact/NN
#   student/NN
#   COVID-19/NNP
#   student/NN
#   class/NN
#   (FACILITY Wang/NNP Learning/NNP Centre/NNP)
#   ’/NNP
#   branch/NN
#   (GPE East/NNP Coast/NNP)
#   May/NNP
#   student/NN
#   class/NN
#   (ORGANIZATION Learning/NNP Point/NNP)
#   May/NNP
#   tuition/NN
#   centre/NN
#   (ORGANIZATION CNA/NNP)
#   Saturday/NNP
#   May/NNP
#   (ORGANIZATION Wang/NNP)
#   Learning/NNP
#   Centre/NNP
#   website/NN
#   (GPE East/NNP)
#   Coast/NNP
#   branch/NN
#   (ORGANIZATION EastGate/NNP)
#   centre/NN
#   units/NNS
#   floors/NNS
#   building/NN
#   (PERSON Wang/NNP Learning/NNP Centre/NNP)
#   “/NNP
#   disinfection/NN
#   ”/NNS
#   May/NNP
#   (ORGANIZATION Ministry/NNP)
#   (GPE Health/NNP)
#   (ORGANIZATION MOH/NNP)
#   people/NNS
#   classroom/NN
#   COVID-19/NNP
#   student/NN
#   AdvertisementAdvertisement/NNP
#   No/NNP
#   branches/NNS
#   (PERSON Wang/NNP Learning/NNP Centre/NNP)
#   outlets/NNS
#   (GPE Singapore/NNP)
#   (PERSON Wang/NNP Learning/NNP Centre/NNP)
#   classes/NNS
#   May/NNP
#   Jun/NNP
#   part/NN
#   measures/NNS
#   centre/NN
#   safety/NN
#   measures/NNS
#   (ORGANIZATION SafeEntry/NNP)
#   mask-wearing/NN
#   Surfaces/NNS
#   interval/NN
#   classes/NNS
#   “/NN
#   Teachers/NNPS
#   symptoms/NNS
#   doctor/NN
#   disinfection/NN
#   services/NNS
#   centres/NNS
#   weekend/NN
#   week/NN
#   Advertisement/NNP
#   MOH/NNP
#   Friday/NNP
#   cases/NNS
#   students/NNS
#   case/NN
#   (GPE Singaporean/NNP)
#   woman/NN
#   tutor/NN
#   (ORGANIZATION Learning/NNP Point/NNP)
#   tuition/NN
#   centre/NN
#   (ORGANIZATION Parkway/NNP Centre/NNP)
#   students/NNS
#   tutor/NN
#   classes/NNS
#   students/NNS
#   (GPE Kong/NNP)
#   Hwa/NNP
#   School/NNP
#   (PERSON St/NNP Stephen/NNP)
#   (ORGANIZATION School/NNP)
#   (PERSON St/NNP Andrew/NNP)
#   (ORGANIZATION Junior/NNP School/NNP)
#   schools/NNS
#   notices/NNS
#   learning/NN
#   detection/NN
#   cases/NNS
#   Download/NNP
#   app/NN
#   subscribe/NN
#   (ORGANIZATION Telegram/NNP)
#   channel/NN
#   updates/NNS
#   coronavirus/NN
#   outbreak/NN
#   https/NN
#   //cna.asia/telegram/NN)

# %% [markdown]
# With the function nltk.ne_chunk(), we can recognize named entities using a classifier, the classifier adds category labels such as PERSON, ORGANIZATION, and GPE.

# %% [markdown]
# ## NER with spaCy
# **spaCy** is an open-source Python library that parses and “understands” large volumes of text.It features NER, POS tagging, dependency parsing, word vectors and more.
#
# <b>Run the following command in Anaconda prompt:</b>
# ```Python
# pip install spacy
# python -m spacy download en_core_web_sm
# ```
#
# We will be using spaCy to perform POS and NER using the same Singapore News dataset. Important the necessary libraries:
# ```Python
# import spacy
# from spacy import displacy
# from collections import Counter
# import en_core_web_sm
# nlp = en_core_web_sm.load()
# ```

# %%
#pip install spacy
# Out:
# Requirement already satisfied: spacy in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: wrapt in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in d:\users\24dit24a\.conda\envs\textanalysis\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ----------------- ---------------------- 5.5/12.8 MB 30.5 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 36.5 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Enter code here
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# One of the nice things about Spacy is that we only need to apply nlp once, the entire background pipeline will return the objects.
#
# spaCy recognizes the following entities:
# * PERSON:      People, including fictional
# * NORP:        Nationalities or religious or political groups
# * FAC:         Buildings, airports, highways, bridges, etc
# * ORG:         Companies, agencies, institutions, etc
# * GPE:         Countries, cities, states
# * LOC:         Non-GPE locations, mountain ranges, bodies of water
# * PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# * EVENT:       Named hurricanes, battles, wars, sports events, etc
# * WORK_OF_ART: Titles of books, songs, etc
# * LAW:         Named documents made into laws
# * LANGUAGE:    Any named language
# * DATE:        Absolute or relative dates or periods
# * TIME:        Times smaller than a day
# * PERCENT:     Percentage, including "%"
# * MONEY:       Monetary values, including unit
# * QUANTITY:    Measurements, as of weight or distance
# * ORDINAL:     “first”, “second”, etc
# * CARDINAL:    Numerals that do not fall under another type
#
# Let's get the entities from the first news.
# ```Python
# # Extract entities from the first new
# from pprint import pprint
#
# doc = nlp(df['Text'][0])
# pprint([(X.text, X.label_) for X in doc.ents])
#
# ```

# %%
# Enter code here
# Extract entities from the first new
from pprint import pprint

doc = nlp(df['Text'][0])
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Eleven', 'CARDINAL'),
#  ('Wang Learning Centre', 'ORG'),
#  ('COVID-19', 'ORG'),
#  ('Wang Learning Centre’s', 'ORG'),
#  ('East Coast', 'LOC'),
#  ('May 9', 'DATE'),
#  ('AdvertisementAdvertisement', 'ORG'),
#  ('Learning Point', 'FAC'),
#  ('May 8', 'DATE'),
#  ('Chinese', 'NORP'),
#  ('CNA', 'ORG'),
#  ('Saturday', 'DATE'),
#  ('May 15', 'DATE'),
#  ('the Wang Learning Centre', 'ORG'),
#  ('East Coast', 'LOC'),
#  ('EastGate', 'PRODUCT'),
#  ('Wang Learning Centre', 'ORG'),
#  ('May 10', 'DATE'),
#  ('the Ministry of Health', 'ORG'),
#  ('COVID-19', 'ORG'),
#  ('AdvertisementAdvertisement', 'ORG'),
#  ('Wang Learning Centre', 'PERSON'),
#  ('eight', 'CARDINAL'),
#  ('Singapore', 'GPE'),
#  ('Wang Learning Centre', 'PERSON'),
#  ('May 16', 'DATE'),
#  ('13', 'CARDINAL'),
#  ('SafeEntry', 'ORG'),
#  ('30-minute', 'TIME'),
#  ('last weekend', 'DATE'),
#  ('this week', 'DATE'),
#  ('Friday', 'DATE'),
#  ('five', 'CARDINAL'),
#  ('COVID-19', 'ORG'),
#  ('50-year-old', 'DATE'),
#  ('Singaporean', 'NORP'),
#  ('Learning Point', 'ORG'),
#  ('Parkway Centre', 'FAC'),
#  ('five', 'CARDINAL'),
#  ('Kong Hwa School', 'ORG'),
#  ("St Stephen's", 'PERSON'),
#  ("St Andrew's", 'PERSON'),
#  ('Junior School', 'ORG'),
#  ('Telegram', 'ORG')]

# %% [markdown]
# Counting the number of entities
# ```Python
# labels = [x.label_ for x in doc.ents]
# Counter(labels)
# ```

# %%
# Enter code here
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'ORG': 16,
#          'DATE': 10,
#          'CARDINAL': 5,
#          'PERSON': 4,
#          'LOC': 2,
#          'FAC': 2,
#          'NORP': 2,
#          'PRODUCT': 1,
#          'GPE': 1,
#          'TIME': 1})

# %% [markdown]
# Get the three most frequent tokens
# ```Python
# items = [x.text for x in doc.ents]
# Counter(items).most_common(3)
# ```

# %%
# Enter code here
items = [x.text for x in doc.ents]
Counter(items).most_common(3)
# Out:
# [('Wang Learning Centre', 4), ('COVID-19', 3), ('East Coast', 2)]

# %% [markdown]
# ## Visualising POS and NER
# spaCy offers an outstanding visualizer called displaCy which helps us to explore the behaviour of the entity recognition model interactively.
#
# Using spaCy’s built-in displaCy visualizer, here’s what the first news and its dependencies look like:
# ```Python
# displacy.render(doc, style='dep', jupyter = True, options = {'distance': 70})
# ```

# %%
# Enter codes here
displacy.render(doc, style='dep', jupyter = True, options = {'distance': 70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e1a697ae9bf0448a8ef12e32e1d62df2-0" class="displacy" width="25250" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Eleven</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">students</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">teacher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">Wang</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">Learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Centre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">required</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">quarantine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">coming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">contact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">student</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1520">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1520">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">recently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1660">tested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1660">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">positive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">COVID-19.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2080">student</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2080">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo

# %% [markdown]
# Finally, we visualize the entity of the first news.
# ```Python
# displacy.render(doc, style='ent', jupyter = True)
# ```

# %%
# Enter codes here
displacy.render(doc, style='ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eleven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  students and a teacher from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have been required to quarantine after coming into contact with another student who recently tested positive for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>The student had attended a class at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  branch in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     East Coast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AdvertisementAdvertisement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>The same student had also attended a class at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Learning Point
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  tuition centre told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).<br><br>According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  website, its
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     East Coast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  branch is located at
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EastGate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The centre occupies several units on different floors in the building. <br><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said it had scheduled a “full professional disinfection” on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ministry of Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (MOH) had also asked them to identify the people who were in the same classroom as the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  positive student.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AdvertisementAdvertisement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>No other branches were affected, said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , which has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  outlets across
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Singapore

# %% [markdown]
# You can pass a list of entity types to restrict the visualization:
# ```Python
# options={'ents':['ORG','DATE']}
# displacy.render(doc, style='ent', jupyter = True, options=options)
# ```

# %%
# Enter codes here
options={'ents':['ORG','DATE']}
displacy.render(doc, style='ent', jupyter = True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Eleven students and a teacher from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have been required to quarantine after coming into contact with another student who recently tested positive for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>The student had attended a class at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  branch in East Coast on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AdvertisementAdvertisement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>The same student had also attended a class at Learning Point on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the Chinese tuition centre told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).<br><br>According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  website, its East Coast branch is located at EastGate. The centre occupies several units on different floors in the building. <br><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wang Learning Centre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said it had scheduled a “full professional disinfection” on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ministry of Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (MOH) had also asked them to identify the people who were in the same classroom as the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  positive student.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AdvertisementAdvertisement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>No other branches were affected, said Wang Learning Centre, which has eight outlets across Singapore.<br><br>Wang Learning Centre will move all classes online from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to Jun 13 as part of enhanced measures.<br><br>The centre said other existing safety measures include
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SafeEntry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  check-in, temperature-taking, as well as mandatory mask-wearing. Surfaces are also disinfected during the 30-minute interval between classes.<br><br>“Teachers are not allowed to come to work if symptoms are spotted and are required to see a doctor immediately. We also hired professional disinfection services to disinfect our centres
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,” they added.<br>Advertisement<br>MOH on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  said that five
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cases, all of them students, have been linked to a previous case, a
# <mark class="entity" style="background: #bfe1d9; paddi

# %% [markdown]
# ### Additional Learning Reference
# 1. Hands-on NLP Project: A Comprehensive Guide to Information Extraction using Python<br/>
# https://www.analyticsvidhya.com/blog/2020/06/nlp-project-information-extraction/
#
# 2. NER using spaCY<br/>
# https://towardsdatascience.com/named-entity-recognition-ner-using-spacy-nlp-part-4-28da2ece57c6

# %% [markdown]
# # Exercise
# You will be using **CovidNews.txt** dataset for this exercise. Perform the following tasks:
#
# 1. Read all text from **CovidNews.txt** into a string
# 2. Perform POS on the Covid News
# 3. Find the top 5 adjectives in the Covid news
# 4. Count the number of entities and visualize the entities

# %%
# Enter your codes here
# Read all text from CovidNews.txt into a string
# Perform POS on the Covid News
# Find the top 5 adjectives in the Covid news
# Count the number of entities and visualize the entities

# %%
# Read all text from CovidNews.txt into a string
with open('CovidNews.txt', 'r') as file:
    content = file.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Read all text from CovidNews.txt into a string
# ----> 2 with open('CovidNews.txt', 'r') as file:
#       3     content = file.read()
#       4 print(content)
#
# File ~\.conda\envs\textanalysis\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CovidNews.txt'

# %%
# Perform POS on the Covid News
pos_tagged = tagPOS(content)  
pos_tagged
# Out:
# [('Taiwan', 'NNP'),
#  ('raised', 'VBD'),
#  ('its', 'PRP$'),
#  ('COVID-19', 'NNP'),
#  ('alert', 'NN'),
#  ('level', 'NN'),
#  ('on', 'IN'),
#  ('Saturday', 'NNP'),
#  ('(', '('),
#  ('May', 'NNP'),
#  ('15', 'CD'),
#  (')', ')'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('capital', 'NN'),
#  (',', ','),
#  ('Taipei', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('surrounding', 'VBG'),
#  ('city', 'NN'),
#  (',', ','),
#  ('bringing', 'VBG'),
#  ('curbs', 'NNS'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('period', 'NN'),
#  ('of', 'IN'),
#  ('two', 'CD'),
#  ('weeks', 'NNS'),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('shut', 'VB'),
#  ('many', 'JJ'),
#  ('venues', 'NNS'),
#  ('and', 'CC'),
#  ('restrict', 'JJ'),
#  ('gatherings', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wake', 'NN'),
#  ('of', 'IN'),
#  ('180', 'CD'),
#  ('new', 'JJ'),
#  ('domestic', 'JJ'),
#  ('infections', 'NNS'),
#  ('.', '.'),
#  ('Masks', 'NNS'),
#  ('are', 'VBP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('worn', 'JJ'),
#  ('outdoors', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('encourages', 'VBZ'),
#  ('work', 'NN'),
#  ('and', 'CC'),
#  ('study', 'NN'),
#  ('from', 'IN'),
#  ('home', 'NN'),
#  (',', ','),
#  ('shutting', 'VBG'),
#  ('cinemas', 'NN'),
#  ('and', 'CC'),
#  ('entertainment', 'NN'),
#  ('spots', 'NNS'),
#  (',', ','),
#  ('while', 'IN'),
#  ('limiting', 'VBG'),
#  ('gatherings', 'NNS'),
#  ('of', 'IN'),
#  ('families', 'NNS'),
#  ('and', 'CC'),
#  ('friends', 'NNS'),
#  ('to', 'TO'),
#  ('five', 'CD'),
#  ('indoors', 'NNS'),
#  ('and', 'CC'),
#  ('10', 'CD'),
#  ('outdoors', 'NNS'),
#  ('.', '.'),
#  ('Taipei', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('has', 'VBZ'),
#  ('already', 'RB'),
#  ('ordered', 'VBN'),
#  ('bars', 'NNS'),
#  (',', ','),
#  ('nightclubs', 'NNS'),
#  ('and', 'CC'),
#  ('similar', 'JJ'),
#  ('venues', 'NNS'),
#  ('to', 'TO'),
#  ('shut', 'VB'),
#  ('.', '.'),
#  ('Health', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Chen', 'NNP'),
#  ('Shih-chung', 'NNP'),
#  ('said', 'VBD'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('level', 'NN'),
#  ('of', 'IN'),
#  ('risk', 'NN'),
#  ("''", "''"),
#  ('in', 'IN'),
#  ('certain', 'JJ'),
#  ('hot', 'JJ'),
#  ('spots', 'NNS'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('Taipei', 'NNP'),
#  ("'s", 'POS'),
#  ('gritty', 'JJ'),
#  ('Wanhua', 'NNP'),
#  ('district', 'NN'),
#  (',', ','),
#  ('had', 'VBD'),
#  ('spurred', 'VBN'),
#  ('the', 'DT'),
#  ('decision', 'NN'),
#  ('to', 'TO'),
#  ('raise', 'VB'),
#  ('the', 'DT'),
#  ('alert', 'JJ'),
#  ('level', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Only', 'RB'),
#  ('by', 'IN'),
#  ('doing', 'VBG'),
#  ('this', 'DT'),
#  ('can', 'MD'),
#  ('infections', 'VB'),
#  ('be', 'VB'),
#  ('dealt', 'VBN'),
#  ('with', 'IN'),
#  ('and', 'CC'),
#  ('controlled', 'VBD'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('told', 'VBD'),
#  ('reporters', 'NNS'),
#  ('.', '.'),
#  ('Taipei', 'NNP'),
#  ('Mayor', 'NNP'),
#  ('Ko', 'NNP'),
#  ('Wen-je', 'NNP'),
#  ('urged', 'VBD'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('stay', 'VB'),
#  ('home', 'RB'),
#  ('as', 'RB'),
#  ('much', 'JJ'),
#  ('as', 'IN'),
#  ('possible', 'JJ'),
#  (',', ','),
#  ('adding', 'VBG'),
#  ('that', 'IN'),
#  ('schools', 'NNS'),
#  ('should', 'MD'),
#  ('teach', 'VB'),
#  ('online', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('During', 'IN'),
#  ('this', 'DT'),
#  ('time', 'NN'),
#  (',', ','),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('have', 'VBP'),
#  ('nothing', 'NN'),
#  ('on', 'IN'),
#  (',', ','),
#  ('then', 'RB'),
#  ('stay', 'VB'),
#  ('at', 'IN'),
#  ('home', 'NN'),
#  ('and', 'CC'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('go', 'VB'),
#  ('out', 'RP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('do', 'VBP'),
#  (',', ','),
#  ('wear', 'VB'),
#  ('a', 'DT'),
#  ('mask', 'NN'),
#  ('to', 'TO'),
#  ('reduce', 'VB'),
#  ('infection', 'NN'),
#  ('from', 'IN'),
#  ('droplets', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Ko', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('doctor', 'NN'),
#  ('by', 'IN'),
#  ('training', 'VBG'),
#  ('.', '.'),
#  ('President', 'NNP'),
#  ('Tsai', 'NNP'),
#  ('Ing-wen', 'NNP'),
#  ("'s", 'POS'),
#  ('spokesman', 'NN'),
#  ('said', 'VBD'),
#  ('she', 'PRP'),
#  ('would', 'MD'),
#  ('reduce', 'VB'),
#  ('the', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('``', '``'),
#  ('unnecessary', 'JJ'),
#  ('meetings', 'NNS'),
#  ("''", "''"),
#  ('or', 'CC'),
#  ('public', 'JJ'),
#  ('events', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('presidential', 'JJ'),
#  ('office', 'NN'),
#  ('is', 'VBZ'),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('Wanhua', 'NNP'),
#  ('.', '.')]

# %%
# Find the top 5 adjectives in the Covid news
tagdict = findtags('JJ', pos_tagged, 5)
for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# JJ [('many', 1), ('restrict', 1), ('new', 1), ('domestic', 1), ('worn', 1)]

# %%
# Count the number of entities and visualize the entities
doc = nlp(content)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Taiwan', 'GPE'),
#  ('COVID-19', 'PRODUCT'),
#  ('Saturday', 'DATE'),
#  ('May 15', 'DATE'),
#  ('Taipei', 'GPE'),
#  ('a period of', 'DATE'),
#  ('two weeks', 'DATE'),
#  ('180', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('five', 'CARDINAL'),
#  ('10', 'CARDINAL'),
#  ('Taipei', 'GPE'),
#  ('Chen Shih-chung', 'PERSON'),
#  ('Taipei', 'GPE'),
#  ('Wanhua district', 'LOC'),
#  ('Taipei', 'GPE'),
#  ('Ko Wen-je', 'PERSON'),
#  ('Ko', 'PERSON'),
#  ("Tsai Ing-wen's", 'PERSON'),
#  ('Wanhua', 'PERSON')]

# %%
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'GPE': 5,
#          'PERSON': 5,
#          'DATE': 4,
#          'CARDINAL': 3,
#          'PRODUCT': 1,
#          'ORDINAL': 1,
#          'LOC': 1})

# %%
items = [x.text for x in doc.ents]
Counter(items).most_common(3)
# Out:
# [('Taipei', 4), ('Taiwan', 1), ('COVID-19', 1)]

# %%
displacy.render(doc, style='dep', jupyter = True, options = {'distance': 70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="34aca4b46cfe48448731c528e8476ed8-0" class="displacy" width="15730" height="382.0" direction="ltr" style="max-width: none; height: 382.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Taiwan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">raised</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">alert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">level</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">Saturday (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">May</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">15)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">capital,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">Taipei,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">surrounding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">city,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">bringing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">curbs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1520">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1520">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">period</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1660">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1660">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">shut</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2080">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2080">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">venues</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN

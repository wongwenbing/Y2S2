# %% [markdown]
# ![NYPLogo.png](attachment:NYPLogo.png)
#
# # Practical 4b: Visualise Text Data
#
# ## Objectives
# * Demonstrate different techniques to extract relevant text for visualisation.

# %% [markdown]
# Text Visualisation includes techniques for visually representing raw text data or the results of text analysis methodologies. Effective and meaningful visualisatipons convince audiences of the message and help them understand the findings. In this practical we will explore the elements that make an effective visualisation and the factors that should be considered when choosing a visual representation of the result of the text analysis.
#
# We will explore examples of text vsiualisation using different visualisation techniques.
#
#
# ## Read the text data
# In this practical, we will be using the dataset in NLTK library for visualisation.

# %%
conda install nltk spacy
# Out:
# Channels:
# Note: you may need to restart the kernel to use updated packages.
#
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\wongw\anaconda3
#
#   added / updated specs:
#     - nltk
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     catalogue-2.0.10           |   py38haa95532_0          34 KB
#     cloudpathlib-0.16.0        |   py38haa95532_1          68 KB
#     confection-0.1.4           |   py38h9909e9c_0          69 KB
#     cymem-2.0.6                |   py38hd77b12b_0          34 KB
#     cython-blis-0.7.9          |   py38h080aedc_0         4.4 MB
#     joblib-1.4.2               |   py38haa95532_0         398 KB
#     markdown-it-py-2.2.0       |   py38haa95532_1         130 KB
#     mdurl-0.1.0                |   py38haa95532_0          19 KB
#     mkl-service-2.4.0          |   py38h2bbff1b_1          44 KB
#     mkl_fft-1.3.8              |   py38h2bbff1b_0         169 KB
#     mkl_random-1.2.4           |   py38h59b6b97_0         230 KB
#     murmurhash-1.0.7           |   py38hd77b12b_0          24 KB
#     nltk-3.9.1                 |   py38haa95532_0         2.3 MB
#     numexpr-2.8.4              |   py38h7b80656_1         128 KB
#     numpy-1.24.3               |   py38h79a8e48_1          11 KB
#     numpy-base-1.24.3          |   py38h8a87ada_1         5.1 MB
#     preshed-3.0.6              |   py38h6c2663c_0          76 KB
#     regex-2024.9.11            |   py38h827c3e9_0         340 KB
#     rich-13.7.1                |   py38haa95532_0         473 KB
#     shellingham-1.5.0          |   py38haa95532_0          19 KB
#     smart_open-5.2.1           |   py38haa95532_0          81 KB
#     spacy-3.7.2                |   py38hef0f399_0         6.2 MB
#     spacy-legacy-3.0.12        |   py38haa95532_0          50 KB
#     spacy-loggers-1.0.4        |   py38haa95532_0          21 KB
#     srsly-2.4.8                |   py38hd77b12b_1         553 KB
#     thinc-8.2.2                |   py38hf497b98_0         982 KB
#     typer-0.9.0                |   py38haa95532_0          83 KB
#     wasabi-0.9.1               |   py38haa95532_0          44 KB
#     weasel-0.3.4               |   py38haa95532_0          96 KB
#     ------------------------------------------------------------
#                                            Total:        22.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          pkgs/main/win-64::catalogue-2.0.10-py38haa95532_0
#   cloudpathlib       pkgs/main/win-64::cloudpathlib-0.16.0-py38haa95532_1
#   confection         pkgs/main/win-64::confection-0.1.4-py38h9909e9c_0
#   cymem              pkgs/main/win-64::cymem-2.0.6-py38hd77b12b_0
#   cython-blis        pkgs/main/win-64::cython-blis-0.7.9-py38h080aedc_0
#   joblib             pkgs/main/win-64::joblib-1.4.2-py38haa95532_0
#   langcodes          pkgs/main/noarch::langcodes-3.3.0-pyhd3eb1b0_0
#   markdown-it-py     pkgs/main/win-64::markdown-it-py-2.2.0-py38haa95532_1
#   mdurl              pkgs/main/win-64::mdurl-0.1.0-py38haa95532_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.8-py38h2bbff1b_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.4-py38h59b6b97_0
#   murmurhash         pkgs/main/win-64::murmurhash-1.0.7-py38hd77b12b_0
#   nltk               pkgs/main/win-64::nltk-3.9.1-py38haa95532_0
#   numpy              pkgs/main/win-64::numpy-1.24.3-py38h79a8e48_1
#   preshed            pkgs/main/win-64::preshed-3.0.6-py38h6c2663c_0
#   regex              pkgs/main/win-64::regex-2024.9.11-py38h827c3e9_0
#   rich               pkgs/main/win-64::rich-13.7.1-py38haa95532_0
#   shellingham        pkgs/main/win-64::shellingham-1.5.0-py38haa95532_0
#   smart_open         pkgs/main/win-64::smart_open-5.2.1-py38haa95532_0
#   spacy              pkgs/main/win-64::spacy-3.7.2-py38hef0f399_0
#   spacy-legacy       pkgs/main/win-64::spacy-legacy-3.0.12-py38haa95532_0
#   spacy-loggers      pkgs/main/win-64::spacy-loggers-1.0.4-py38haa95532_0
#   srsly              pkgs/main/win-64::srsly-2.4.8-py38hd77b12b_1
#   thinc              pkgs/main/win-64::thinc-8.2.2-py38hf497b98_0
#   typer              pkgs/main/win-64::typer-0.9.0-py38haa95532_0
#   wasabi             pkgs/main/win-64::wasabi-0.9.1-py38haa95532_0
#   weasel             pkgs/main/win-64::weasel-0.3.4-py38haa95532_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2024.9.24-haa95532_0 --> 2024.11.26-haa95532_0
#   mkl                                            2020.2-256 --> 2023.1.0-h6b88ed4_46358
#   mkl-service                          2.3.0-py38h196d8e1_0 --> 2.4.0-py38h2bbff1b_1
#   numexpr                              2.7.0-py38hdce8814_0 --> 2.8.4-py38h7b80656_1
#   numpy-base                          1.19.2-py38ha3acd2a_0 --> 1.24.3-py38h8a87ada_1
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# Importing data
import nltk
from nltk.corpus import webtext
nltk.download('webtext')
nltk.download('punkt')
nltk.download('punkt_tab')

wt_sentences = webtext.sents('firefox.txt')
wt_words = webtext.words('firefox.txt')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\wongw\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\wongw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\wongw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Import necessary libraries
# Import library for computing frequency

# %%
# Import libraries
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string

# %% [markdown]
# ## Check number of words in teh data
# Execute the code below to count the number of words

# %%
# count number of words
print(len(wt_sentences))
print(len(wt_words))
# Out:
# 1144
# 102457

# %% [markdown]
# ## Compute the frequency of all words
# Execute the following codes to generate the frequency for all the words:
# ```Python
# # generate frequency for all the words
# freq_dist = nltk.FreqDist(wt_words)
#
# # show the top few results
# freq_dist
# ```

# %%
# generate frequency for all the words
freq_dist = nltk.FreqDist(wt_words)

# show the top few results
freq_dist
# Out:
# FreqDist({'.': 2428, 'in': 2203, 'to': 2130, '"': 1971, 'the': 1762, "'": 1507, 'not': 1472, '-': 1372, 'when': 1255, 'on': 1193, ...})

# %% [markdown]
# Execute the following codes to sort the frequency in descending order:
# ```Python
# sorted_freqdist = sorted(freq_dist, key=freq_dist.__getitem__, reverse=True)
# sorted_freqdist
# ```

# %%
sorted_freqdist = sorted(freq_dist, key=freq_dist.__getitem__, reverse=True)
sorted_freqdist
# Out:
# ['.',
#  'in',
#  'to',
#  '"',
#  'the',
#  "'",
#  'not',
#  '-',
#  'when',
#  'on',
#  'a',
#  'is',
#  't',
#  'and',
#  'of',
#  '(',
#  'page',
#  'for',
#  'with',
#  ')',
#  'window',
#  'Firefox',
#  'does',
#  'from',
#  'open',
#  ':',
#  'menu',
#  'should',
#  'bar',
#  'tab',
#  'doesn',
#  'after',
#  'Firebird',
#  'new',
#  'work',
#  'browser',
#  'if',
#  'be',
#  '0',
#  'toolbar',
#  'button',
#  'bookmarks',
#  'dialog',
#  'bookmark',
#  'as',
#  'file',
#  'URL',
#  'download',
#  'crashes',
#  'I',
#  'no',
#  'text',
#  'are',
#  'or',
#  'up',
#  'crash',
#  'click',
#  'tabs',
#  'Bookmarks',
#  'link',
#  '/',
#  'firefox',
#  'manager',
#  '+',
#  'using',
#  'it',
#  'Mozilla',
#  'default',
#  'error',
#  'all',
#  'an',
#  'clicking',
#  's',
#  'windows',
#  'search',
#  'folder',
#  ']',
#  'Phoenix',
#  '1',
#  'at',
#  'icon',
#  'Manager',
#  'by',
#  'this',
#  'site',
#  'can',
#  'files',
#  'Page',
#  'fails',
#  'causes',
#  'use',
#  'close',
#  '[',
#  'opening',
#  'Toolbar',
#  'Add',
#  'has',
#  'Bookmark',
#  'right',
#  'display',
#  'down',
#  'that',
#  'theme',
#  'box',
#  'Download',
#  '9',
#  'The',
#  'pages',
#  'firebird',
#  'only',
#  'url',
#  'while',
#  'have',
#  'image',
#  'links',
#  'When',
#  'location',
#  'Crash',
#  'option',
#  'scroll',
#  'load',
#  'cannot',
#  'Options',
#  'address',
#  '>',
#  'Can',
#  'start',
#  'password',
#  'com',
#  'do',
#  '->',
#  'extension',
#  'install',
#  'back',
#  'buttons',
#  'history',
#  'loading',
#  'don',
#  'you',
#  'web',
#  'form',
#  'instead',
#  'wrong',
#  'No',
#  'show',
#  'mouse',
#  'build',
#  'sidebar',
#  'about',
#  'focus',
#  'will',
#  'http',
#  '://',
#  'set',
#  'broken',
#  'Windows',
#  'popup',
#  'some',
#  'icons',
#  'opens',
#  'drop',
#  'context',
#  'into',
#  'autocomplete',
#  '8',
#  'preferences',
#  'missing',
#  'screen',
#  'one',
#  'save',
#  'Open',
#  'field',
#  'print',
#  'Ctrl',
#  'working',
#  'images',
#  'profile',
#  'other',
#  'options',
#  'mozilla',
#  'add',
#  'New',
#  'Find',
#  'Browser',
#  'startup',
#  'any',
#  'change',
#  'size',
#  'list',
#  'javascript',
#  'opened',
#  'first',
#  'type',
#  'user',
#  'too',
#  'trying',
#  'but',
#  '2',
#  'like',
#  '<',
#  'extensions',
#  'displayed',
#  'multiple',
#  'Save',
#  'phoenix',
#  'selected',
#  'Cannot',
#  'time',
#  'i',
#  'won',
#  'shows',
#  'properly',
#  'over',
#  'appears',
#  'view',
#  'Error',
#  'X',
#  'name',
#  'correctly',
#  'always',
#  ';',
#  'left',
#  'item',
#  'hangs',
#  'appear',
#  'background',
#  'menus',
#  'UI',
#  'directory',
#  'input',
#  'application',
#  'themes',
#  'version',
#  'message',
#  'same',
#  'blank',
#  'View',
#  'Web',
#  'www',
#  'File',
#  'middle',
#  'Tab',
#  'OS',
#  'even',
#  'go',
#  'folders',
#  'scrolling',
#  'html',
#  'keyboard',
#  'off',
#  'without',
#  'non',
#  'Tools',
#  'Menu',
#  'line',
#  'my',
#  'Preferences',
#  'proxy',
#  'saved',
#  'out',
#  '6',
#  'sites',
#  'IE',
#  'Clicking',
#  'select',
#  'content',
#  'Search',
#  'home',
#  'than',
#  'update',
#  'shortcut',
#  'items',
#  'get',
#  'under',
#  'source',
#  'preview',
#  'current',
#  'closing',
#  '&',
#  'find',
#  'Javascript',
#  'clicked',
#  'cookies',
#  '|',
#  'plugin',
#  'empty',
#  'key',
#  'History',
#  'remove',
#  'running',
#  '...',
#  'disabled',
#  'longer',
#  'support',
#  'dropdown',
#  'status',
#  'installer',
#  'installing',
#  '7',
#  'works',
#  'displays',
#  'document',
#  'allow',
#  'JavaScript',
#  'Password',
#  'shown',
#  'After',
#  'top',
#  'downloads',
#  'OK',
#  'last',
#  'mode',
#  'Folder',
#  'more',
#  'enter',
#  'drag',
#  'website',
#  'freezes',
#  'wheel',
#  'login',
#  'launch',
#  'another',
#  'needs',
#  'bug',
#  '3',
#  'About',
#  'ctrl',
#  'being',
#  'Unable',
#  'Print',
#  'function',
#  'Installer',
#  'Text',
#  'Help',
#  'used',
#  'disable',
#  'Extension',
#  'js',
#  'Use',
#  'problem',
#  'try',
#  'installed',
#  'downloading',
#  'XML',
#  'make',
#  'Need',
#  '%',
#  'settings',
#  'Linux',
#  'As',
#  'cursor',
#  'enabled',
#  'still',
#  'Java',
#  'run',
#  'closed',
#  'found',
#  '::',
#  'small',
#  'builds',
#  'main',
#  'chrome',
#  'Tabs',
#  'system',
#  'access',
#  'Mac',
#  '=',
#  'its',
#  'installation',
#  '[@',
#  'browsing',
#  'slow',
#  'Profile',
#  'breaks',
#  'Location',
#  '()',
#  'Bar',
#  'flash',
#  'Wrong',
#  'certain',
#  'Image',
#  'Default',
#  'changes',
#  'loaded',
#  'two',
#  'characters',
#  'pop',
#  'URLs',
#  'Link',
#  'selection',
#  'server',
#  'loads',
#  'between',
#  'information',
#  'CPU',
#  'switching',
#  'code',
#  'style',
#  'then',
#  'auto',
#  'import',
#  '4',
#  'Window',
#  'incorrectly',
#  'command',
#  'was',
#  'Not',
#  '..."',
#  'gets',
#  'webpage',
#  'complete',
#  'CSS',
#  'FireFox',
#  'customize',
#  'second',
#  '!',
#  'large',
#  'via',
#  'delete',
#  'Sidebar',
#  'exe',
#  'tag',
#  'me',
#  'Internet',
#  'Popup',
#  'java',
#  'changing',
#  'entry',
#  'different',
#  'way',
#  'Dialog',
#  'Flash',
#  'until',
#  'full',
#  'stop',
#  'pref',
#  'selecting',
#  'connection',
#  'problems',
#  'nothing',
#  'dll',
#  'there',
#  'already',
#  'remember',
#  'through',
#  'boxes',
#  'restart',
#  'incorrect',
#  '5',
#  'cache',
#  'homepage',
#  'Info',
#  'In',
#  'very',
#  'rendering',
#  'warning',
#  'which',
#  'cookie',
#  'stops',
#  'results',
#  'arrow',
#  'org',
#  'preference',
#  'character',
#  'Downloads',
#  'mail',
#  'title',
#  'data',
#  'XP',
#  'Form',
#  'available',
#  'Customize',
#  'Autocomplete',
#  'Remove',
#  'Make',
#  '?',
#  'clear',
#  'times',
#  'copy',
#  'Source',
#  'sometimes',
#  'google',
#  'request',
#  'HTML',
#  'makes',
#  'Theme',
#  'submit',
#  'fields',
#  'create',
#  'starting',
#  'This',
#  'before',
#  'them',
#  'Extensions',
#  'Opening',
#  'uses',
#  'prefs',
#  'visible',
#  'info',
#  'gives',
#  'alert',
#  'old',
#  'properties',
#  'keys',
#  'goes',
#  'lost',
#  '="',
#  'blocking',
#  'favicon',
#  'disappear',
#  'toolbars',
#  'doesnt',
#  'upon',
#  'viewing',
#  'automatically',
#  'need',
#  'hang',
#  'switch',
#  'showing',
#  'Back',
#  'each',
#  'external',
#  'Home',
#  'refresh',
#  'string',
#  'All',
#  'blocked',
#  '100',
#  'during',
#  'setting',
#  'unable',
#  'many',
#  'Right',
#  'Thunderbird',
#  'navigation',
#  'move',
#  'every',
#  'space',
#  'downloaded',
#  'contains',
#  'Middle',
#  'double',
#  'active',
#  'Option',
#  'disk',
#  'If',
#  'Address',
#  'scrollbar',
#  'expand',
#  'session',
#  'Images',
#  'Go',
#  'completely',
#  'personal',
#  'color',
#  'fonts',
#  'forms',
#  'updated',
#  'where',
#  'value',
#  'closes',
#  'prompt',
#  'monitor',
#  'within',
#  'desktop',
#  'nightly',
#  'render',
#  'linux',
#  'reload',
#  'Yahoo',
#  'release',
#  'deleted',
#  'end',
#  'passwords',
#  'app',
#  'inside',
#  'next',
#  'Context',
#  'forward',
#  'possible',
#  'part',
#  'added',
#  'textbox',
#  'feature',
#  'Show',
#  'just',
#  'Themes',
#  'Auto',
#  'Alt',
#  'Downloading',
#  'program',
#  'help',
#  'Enter',
#  'A',
#  'so',
#  'been',
#  'long',
#  'plugins',
#  'isn',
#  'choose',
#  'RFE',
#  'shortcuts',
#  'Toolbars',
#  'CTRL',
#  'itself',
#  'Update',
#  'usage',
#  'ability',
#  'Implement',
#  'order',
#  'ignored',
#  'area',
#  'twice',
#  'position',
#  'Preview',
#  'disappears',
#  'existing',
#  'Mouse',
#  'Click',
#  'behaviour',
#  'edit',
#  'e',
#  'cause',
#  'see',
#  'displaying',
#  'again',
#  'filename',
#  'deleting',
#  'https',
#  'local',
#  'cust',
#  'adding',
#  'remote',
#  'table',
#  'accessing',
#  'dragging',
#  'Ability',
#  'typing',
#  'network',
#  'action',
#  'Site',
#  'immediately',
#  'starts',
#  'created',
#  'certificate',
#  'saving',
#  'fail',
#  'font',
#  'handling',
#  'popups',
#  'Crashes',
#  'enable',
#  'due',
#  'css',
#  'cancel',
#  'able',
#  'hidden',
#  'panel',
#  'Close',
#  'specific',
#  'Set',
#  'HTTP',
#  'PDF',
#  'failed',
#  'email',
#  'Change',
#  'previous',
#  'could',
#  'stored',
#  'Start',
#  'net',
#  'Shift',
#  'send',
#  'rendered',
#  'User',
#  'checkbox',
#  'typed',
#  'Using',
#  'config',
#  'Cookie',
#  'checked',
#  'memory',
#  'above',
#  'resize',
#  'imported',
#  'number',
#  'failure',
#  'tooltip',
#  'now',
#  'contents',
#  'pdf',
#  'Full',
#  'Icon',
#  'functionality',
#  'Double',
#  'It',
#  're',
#  'username',
#  'entered',
#  'bad',
#  'href',
#  'event',
#  'visiting',
#  'autoscroll',
#  'changed',
#  'Don',
#  'removed',
#  'stay',
#  'script',
#  'attempting',
#  'tree',
#  'Privacy',
#  'x',
#  'effect',
#  'single',
#  'state',
#  'control',
#  'exception',
#  'fullscreen',
#  'creates',
#  'shift',
#  'responding',
#  'path',
#  'present',
#  'Google',
#  'dialogs',
#  'crashed',
#  'anymore',
#  'plug',
#  'locks',
#  'frame',
#  'console',
#  'zip',
#  '*',
#  'secure',
#  'seems',
#  'Personal',
#  'Scroll',
#  'respond',
#  'containing',
#  'launching',
#  'place',
#  'going',
#  'overflow',
#  'Get',
#  'black',
#  'Selecting',
#  'side',
#  'keyword',
#  'loses',
#  'behavior',
#  'accept',
#  'column',
#  '--',
#  'bars',
#  'shouldn',
#  'says',
#  'entries',
#  'printing',
#  'websites',
#  'On',
#  'header',
#  'never',
#  'Security',
#  'Screen',
#  'xul',
#  'jar',
#  'blocker',
#  'applet',
#  'bottom',
#  'width',
#  'paste',
#  'what',
#  'Cancel',
#  'Allow',
#  'anything',
#  'Display',
#  'Install',
#  'Manage',
#  'away',
#  'pressing',
#  'Menus',
#  'once',
#  'Request',
#  'ignores',
#  'specified',
#  'returns',
#  'exit',
#  'include',
#  'Build',
#  'tags',
#  'random',
#  'parsing',
#  '\\',
#  'tabbed',
#  'MozillaFirebird',
#  'attribute',
#  'stylesheet',
#  'DOM',
#  'Edit',
#  'Bad',
#  'authentication',
#  'Mail',
#  'cut',
#  'Icons',
#  'domain',
#  'Some',
#  'block',
#  'tools',
#  'Should',
#  'object',
#  'w',
#  'loop',
#  'takes',
#  'yahoo',
#  'Advanced',
#  'Font',
#  'Type',
#  'frames',
#  'Explorer',
#  'types',
#  'process',
#  'Desktop',
#  'correct',
#  'Enable',
#  'tries',
#  'take',
#  'Please',
#  'renders',
#  'sort',
#  'applications',
#  'With',
#  'Cookies',
#  'Plugin',
#  'favicons',
#  'Problem',
#  'Incorrect',
#  'Create',
#  'fine',
#  'check',
#  'pops',
#  'keeps',
#  'defined',
#  'freeze',
#  'several',
#  '")',
#  'needed',
#  'MS',
#  'XPI',
#  'Installing',
#  'root',
#  'port',
#  'elements',
#  'profiles',
#  'notification',
#  'entering',
#  'keywords',
#  'target',
#  'rdf',
#  'Inspector',
#  'called',
#  'made',
#  'customization',
#  'throbber',
#  'fix',
#  'Navigation',
#  'restore',
#  'standard',
#  'Keyboard',
#  'security',
#  'hide',
#  'invalid',
#  'look',
#  '10',
#  'defaults',
#  'scrollbars',
#  'big',
#  'looks',
#  'latest',
#  'engine',
#  '."',
#  '".',
#  'dual',
#  'undefined',
#  'gtk2',
#  'exist',
#  'listed',
#  '("',
#  'embedded',
#  'FB',
#  'Feature',
#  'given',
#  'collapse',
#  'though',
#  'Missing',
#  'Import',
#  'becomes',
#  'arrows',
#  'urlbar',
#  'os',
#  'Do',
#  'strange',
#  'sheet',
#  'updates',
#  'pointer',
#  'brings',
#  'trunk',
#  'Status',
#  'setup',
#  'extra',
#  'Load',
#  'SSL',
#  'Does',
#  'remains',
#  'want',
#  'Links',
#  'spaces',
#  'quit',
#  'turn',
#  'Clear',
#  'word',
#  'wont',
#  'hand',
#  'Select',
#  'Empty',
#  'FTP',
#  'seconds',
#  'visited',
#  'Printing',
#  'reset',
#  'Netscape',
#  'element',
#  'xml',
#  'result',
#  'started',
#  'branch',
#  'Button',
#  'mac',
#  'updating',
#  'separator',
#  'manage',
#  'high',
#  'Quick',
#  'implement',
#  'would',
#  'refuses',
#  'customizing',
#  'give',
#  'group',
#  'configuration',
#  'editing',
#  'moving',
#  'Support',
#  'Drag',
#  'because',
#  'mailto',
#  'pressed',
#  'own',
#  'disappeared',
#  'internet',
#  'border',
#  'editor',
#  'client',
#  'general',
#  'resizing',
#  'also',
#  'unless',
#  'There',
#  'stays',
#  'based',
#  'alternate',
#  'become',
#  'read',
#  'finished',
#  'alt',
#  'named',
#  'components',
#  'Parsing',
#  'play',
#  'instance',
#  'choosing',
#  'remembered',
#  'behind',
#  'Saved',
#  'animated',
#  'secondary',
#  'attempt',
#  'engines',
#  'XUL',
#  '#',
#  'patch',
#  'progress',
#  'JS',
#  'hover',
#  'colors',
#  'building',
#  'General',
#  'how',
#  'removing',
#  'F',
#  ...]

# %% [markdown]
# ## Consider words with length greater than 3
# Excute the code below to filter and keep only words/terms if their frequency is greater than 3.
# ```Python
# # create a dictionary of key and value
# # keep words only if their frequency is > 3
# filtered_words = dict([(k,v) for k,v in freq_dist.items() if len(k)>3])
#
# # create frequency distribution of the filtered words
# freq_dist = nltk.FreqDist(filtered_words)
#
# # plot the frequency distribution of the top 50 words
# freq_dist.plot(50, cumulative=False)
# ```

# %%
conda install matplotlib
# Out:
# Channels:
# Note: you may need to restart the kernel to use updated packages.
#
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# create a dictionary of key and value
# keep words only if their frequency is > 3
filtered_words = dict([(k,v) for k,v in freq_dist.items() if len(k)>3])

# create frequency distribution of the filtered words
freq_dist = nltk.FreqDist(filtered_words)

# plot the frequency distribution of the top 50 words
freq_dist.plot(50, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## Build Wordcloud
# A word cloud in Python visually represents text data. Also called a tag cloud, it uses different font sizes and colors to highlight the importance of each word. This way, the most prominent terms will come across to the user. Wordcloud is the pictorial representation of the most frequently repeated words representing the size of the word.
#
# To install the wordcloud library:
# > Type this command in jupyter or anaconda prompt: **pip install wordcloud**

# %%
conda install wordcloud
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\wongw\anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.9.3            |   py38h2bbff1b_0         311 KB
#     ------------------------------------------------------------
#                                            Total:         311 KB
#
# The following NEW packages will be INSTALLED:
#
#   wordcloud          pkgs/main/win-64::wordcloud-1.9.3-py38h2bbff1b_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# build wordcloud
from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(freq_dist)

# plot the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Exercise
# Try the following tasks:
# 1. Remove the stop words and then build the word cloud.
#
# You can use the following codes to remove stopwords:

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# import stopwords
stop = stopwords.words('english')
filtered_words=[x for x in wt_words if x not in stop]
filtered_words

# create frequency distribution of the filtered words
freq_dist = nltk.FreqDist(filtered_words)

# plot the frequency distribution of the top 50 words
freq_dist.plot(50, cumulative=False)

wcloud = WordCloud().generate_from_frequencies(freq_dist)
plt.imshow(wcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wongw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Network Graph
# Network visualisation are the current state of the art for text, as shown by the predominance of network style visualisations. They are particularly popular for social network analysis. Such graphs are useful to illustrate relationships between entities, documents, and even concepts within a corpus.
#
# **textnets** represents collections of texts as network of documents and words.
#
# To install the textnets library and download the en_core_web_sm trained English pipeline from spacy:
# > Type this command in jupyter or anaconda prompt:
#
# > **pip install --user textnets**
#
# Should you encounter error in installing textnets, do look through the error code to understand.
# For the following error message , it may suggest there is missing component in Microsoft Visual C++ file:
# E.g. error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools"
#
# Suggested Components for installation:
#
# - Visual C++ Build tools core features.
#
# - MSVC toolset C++ 2019 v142 (x86,x64).
#
# - Visual C++ 2019 Redistributable Update.
#
# - Windows 10 SDK (10.0.17763.0) for Desktop C++.
#
# > **pip install spacy**
#
# > **!python -m spacy download en_core_web_sm**
#
# Let's walkthrough the steps to analyse and visualise text data using **textnets**. We start with importing the library. You can set a fixed seed to ensure that the results are reproducible across runs.
#
# ```Python
# # import library
# import textnets as tn
#
# # fixed seed for reproducible
# tn.params['seed']=42
# ```

# %%
conda install textnets
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We will construct the corpus using the example data from textnets. **moon_landing** is example dataset with newspaper headlines about the Apollo 11 landing. The corpus contains 7 documents.
#
# ```Python
# # construct corpus
# corpus = tn.Corpus(tn.examples.moon_landing)
# corpus
# ```

# %%
# import library
import textnets as tn

# fixed seed for reproducible
tn.params['seed']=42

# %%
# construct corpus
corpus = tn.Corpus(tn.examples.moon_landing)
corpus
# Out:
# <Corpus with 7 documents using language model 'en_core_web_sm'>

# %% [markdown]
# Next, we will create the textnet. The corpus is tokenized with all defaults (removing stop words, applying stemming, and removing punctuation marks, numbers, URLs, etc). The min_docs allow us to set the minimum number of documents a word should appear. In this case, we are setting it to one, opting to keep even words that appear in only one document (that is, a single newspaper headline).
#
# When dealing with large corpora, you may also want to set the remove_weak_edges to True to remove edges with a weight far below the average. This will result in a sparser graph.
#
# ```Python
# # create textnet
# t = tn.Textnet(corpus.tokenized(), min_docs=1)
#
# # plot the textnet
# t.plot(label_nodes=True,
#        show_clusters=True)
# ```
# The show_clusters options identifies document-term groups that appear to form par of the same theme in the texts.

# %%
# create textnet
t = tn.Textnet(corpus.tokenized(), min_docs=1)

# plot the textnet
t.plot(label_nodes=True,
       show_clusters=True)
# Out:
#   0%|          | 0/7 [00:00<?, ?docs/s]

# %% [markdown]
# We can also visualise the term network. Aside from visualisation, we can also analyse our corpus using network metrics.
#
# ```Python
# # create term network
# words = t.project(node_type="term")
# ```
# We will plot the term network scaling nodes according to their betweenness centrality, and pruning edges from the network using "backbone extraction". Instead of showing the clusters, we will use color_clusters to color nodes according to their partition. We can also filter nodel labels, labeling only those nodes that have a betweenness centrality score above the media. This is particularly useful in high-order networks where labeling every single node would cause too much visual clutter.
# ```Python
# # plot the term network
# words.plot(label_nodes=True,
#            scale_nodes_by="betweenness",
#            color_clusters=True,
#            alpha=0.5,
#            edge_width=[10*w for w in words.edges["weight"]],
#            edge_opacity=0.4,
#            node_label_filter=lambda n: n.betweenness() > words.betweenness.median())
#
# ```

# %%
# create term network
words = t.project(node_type="term")
# plot the term network
words.plot(label_nodes=True,
           scale_nodes_by="betweenness",
           color_clusters=True,
           alpha=0.5,
           edge_width=[10*w for w in words.edges["weight"]],
           edge_opacity=0.4,
           node_label_filter=lambda n: n.betweenness() > words.betweenness.median())
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# /Users/wong/.local/lib/python3.11/site-packages/textnets/network.py:889: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   return quad(integrand, 0, norm_weight, args=(degree))
#   0%|          | 0/8 [00:00<?, ?edges/s]

# %% [markdown]
# ## Additional Learning
# Refer to this guide to find out more on textnets:
# 1. https://textnets.readthedocs.io/en/stable/tutorial.html#example

# %% [markdown]
# ### Exercise
# Load the **tripadvisor_hotel_reviews.csv** dataset into panda dataframe. Try the following tasks:
# 1. Create a network graph for analysis
#
# You can use the following codes to create a corpus from Pandas:
# ```Python
# corpus = tn.Corpus.from_df(df, doc_col="Review")
# ```
